# %% [markdown]
# <div style="text-align: center; font-size: 40px; font-weight: bold;">
#     Train Model Deeplabv3+ Architecture
# </div>

# %% [markdown]
# # Libraries

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os
import cv2
from PIL import Image
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras import backend as K
# Out:
# 2026-03-06 08:00:21.427767: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-06 08:00:21.434221: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-03-06 08:00:21.441491: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8473] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-03-06 08:00:21.444163: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1471] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-03-06 08:00:21.450024: I tensorflow/core/platform/cpu_feature_guard.cc:211] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Load Data

# %%
IMG_SIZE = (512, 512)

def load_image(img_path, mask_path):
    # ----- image -----
    img = tf.io.read_file(img_path)
    img = tf.image.decode_bmp(img, channels=3)   # gambar input RGB
    img = tf.image.resize(img, (IMG_SIZE[0], IMG_SIZE[1]))
    img = tf.cast(img, tf.float32) / 255.0

    # ----- mask -----
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_bmp(mask, channels=0)   # biarkan sesuai file
    mask = tf.image.resize(mask, (IMG_SIZE[0], IMG_SIZE[1]), method="nearest")
    
    # pastikan hanya 1 channel
    if tf.shape(mask)[-1] != 1:
        mask = tf.image.rgb_to_grayscale(mask)

    # ubah ke {0,1}
    mask = tf.cast(mask > 127, tf.float32)

    return img, mask

def make_dataset(img_dir, mask_dir, batch_size=4, shuffle=True):
    img_files = sorted([os.path.join(img_dir, f) for f in os.listdir(img_dir)])
    mask_files = sorted([os.path.join(mask_dir, f) for f in os.listdir(mask_dir)])
    ds = tf.data.Dataset.from_tensor_slices((img_files, mask_files))
    ds = ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
    if shuffle:
        ds = ds.shuffle(buffer_size=100)
    ds = ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return ds

train_ds = make_dataset("project/Poreseg/Data_splitK4/train/images", "project/Poreseg/Data_splitK4/train/masks", batch_size=4)
val_ds   = make_dataset("project/Poreseg/Data_splitK4/valid/images", "project/Poreseg/Data_splitK4/valid/masks", batch_size=4, shuffle=False)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772784022.779828    1362 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1772784022.805389    1362 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1772784022.806360    1362 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1772784022.808137    1362 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1772784022.809015    1362 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1772784022.809834    1362 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1772784022.880524    1362 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1772784022.881301    1362 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1772784022.881963    1362 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-03-06 08:00:22.882631: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6974 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 5070, pci bus id: 0000:01:00.0, compute capability: 12.0

# %%
def dice_loss(y_true, y_pred, smooth: float = 1e-6) -> tf.Tensor:
    """
    Computes the Dice loss for image segmentation.
    
    Args:
        y_true: Ground truth binary mask.
        y_pred: Predicted mask.
        smooth (float): Smoothing factor to avoid division by zero.
    
    Returns:
        tf.Tensor: Dice loss value.
    """
    y_true = tf.cast(y_true, tf.float32)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    
    return 1 - ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))

# %%
def iou_metric(y_true, y_pred, thr=0.5, smooth=1.0):
    y_pred_bin = tf.cast(y_pred > thr, tf.float32)
    inter = tf.reduce_sum(y_true * y_pred_bin, axis=[1,2,3])
    union = tf.reduce_sum(y_true, axis=[1,2,3]) + tf.reduce_sum(y_pred_bin, axis=[1,2,3]) - inter
    return tf.reduce_mean((inter + smooth) / (union + smooth))

# %%
def segnet(input_shape=(512, 512, 3)):  # ← 3 channel
    inp = layers.Input(shape=input_shape)

    # Encoder
    x = layers.Conv2D(64, 3, padding='same', activation='relu')(inp)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(64, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    p1 = layers.MaxPooling2D(2)(x)

    x = layers.Conv2D(128, 3, padding='same', activation='relu')(p1)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(128, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    p2 = layers.MaxPooling2D(2)(x)

    x = layers.Conv2D(256, 3, padding='same', activation='relu')(p2)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(256, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    p3 = layers.MaxPooling2D(2)(x)

    x = layers.Conv2D(512, 3, padding='same', activation='relu')(p3)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)

    # Decoder
    x = layers.Conv2DTranspose(256, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(256, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2DTranspose(128, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(128, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2DTranspose(64, 3, strides=2, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(64, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)

    out = layers.Conv2D(1, 1, activation='sigmoid')(x)  # mask tetap 1 channel
    return models.Model(inp, out, name="SegNetBinary512_RGB")

model = segnet(input_shape=(512, 512, 3))

# %%
# Kompilasi model
# ======= Kompilasi Model =======
model.compile(optimizer='adam',
              loss=dice_loss,
              metrics=['accuracy', iou_metric])

# ======= Callbacks =======
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

lr_reduce = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.5, 
                              patience=5, 
                              min_lr=1e-6,
                              verbose=1)

model_checkpoint = ModelCheckpoint('project/Poreseg/Model/model_segnetK4.keras', 
                                   monitor='val_loss', 
                                   save_best_only=True, 
                                   verbose=1)

callbacks = [early_stop, lr_reduce, model_checkpoint]
# ======= Training Contoh =======
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 2026-03-06 08:00:24.911818: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:1026] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inSegNetBinary512_RGB/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2026-03-06 08:00:25.269642: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90701
# W0000 00:00:1772784025.331712    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.340070    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.340794    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.342731    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.343668    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.344870    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.350463    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.351862    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.354372    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.356375    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.364950    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.386315    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.391804    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.398733    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.404778    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.411350    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.419565    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.426378    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.434093    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.442694    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.451985    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.462446    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.473746    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.489064    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.508860    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.641815    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.643415    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.646577    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.649146    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.652023    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.655732    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.658178    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.661962    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.665485    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.668801    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.672256    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.675771    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.681211    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.688201    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.696813    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.701625    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.705634    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.709643    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.715056    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.722448    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.727351    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.734018    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.739935    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.746876    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.753826    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.761049    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.770280    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.781652    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.795187    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.800256    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.802145    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.804038    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.806312    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.808376    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.811034    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.814492    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.817580    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.820863    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.824278    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.827968    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.832684    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.837407    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.846845    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.850101    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.853222    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.856551    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.860619    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.865188    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.869996    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.875499    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.882114    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.888759    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.895890    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.903375    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.911410    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.920140    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.936158    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.939189    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.940797    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.942105    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.944036    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.946225    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.949371    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.953085    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.955557    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.958986    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.962696    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.966552    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.969659    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784025.973554    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# ''+ptx85' is not a recognized feature for this target (ignoring feature)
# +ptx85' is not a recognized feature for this target (ignoring feature)
# ''+ptx85+ptx85' is not a recognized feature for this target' is not a recognized feature for this target (ignoring feature)
#  (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# W0000 00:00:1772784026.245121    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.247651    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.249144    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.250699    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.271087    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.274028    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.276577    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.279210    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.282275    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.284883    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# W0000 00:00:1772784026.323128    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.325815    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.329101    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.332800    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.336784    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.340735    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.345543    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.351448    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.357333    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.364179    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.370978    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.377999    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.386432    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.394536    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.408966    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.413984    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.415898    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.417850    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.420768    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.423928    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.426991    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.429970    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.433733    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.437190    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.450696    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.457422    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.461428    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.465953    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.470838    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.478313    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.483524    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.489732    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.495946    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.502953    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.509830    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.517518    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.526399    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.538362    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.551318    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.557620    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.560483    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.564149    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.567932    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.571946    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.575499    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.580394    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.586403    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.592033    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.622587    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.645107    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.687269    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.700859    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.707158    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.713442    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.720454    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.728290    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.735662    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.742715    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.752080    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.760827    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.771694    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.783322    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.798433    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784026.810722    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772784027.014533    1437 service.cc:146] XLA service 0x7aa6dcc034a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1772784027.014548    1437 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 5070, Compute Capability 12.0
# 2026-03-06 08:00:27.017149: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# I0000 00:00:1772784027.046638    1437 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# W0000 00:00:1772784027.117851    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.121324    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.125005    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.131734    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.138702    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.142585    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.147444    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.152635    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.163314    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.175592    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.185235    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.199911    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.322040    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.800044    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.806315    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.812113    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.818517    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.824462    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.832480    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.839881    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.848354    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.856836    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.865845    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.872324    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.881722    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.898364    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.912699    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.920625    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784027.941138    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# W0000 00:00:1772784030.523215    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.525573    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.527984    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.530780    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.533438    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.536142    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.538926    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.541766    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.545322    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.549527    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.554964    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.559746    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.564590    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.569265    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.576902    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.585506    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.610445    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.616730    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.619783    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.622361    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.625196    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.628871    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.632354    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.637255    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.640899    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.644774    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.649931    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.654762    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.658486    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.662036    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.668849    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784030.683857    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# W0000 00:00:1772784031.771757    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.774607    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.777724    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.781103    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.784184    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.787276    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.790535    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.794678    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.801574    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.809097    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.817307    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.832045    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.836852    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.840370    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.845128    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.850617    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.854829    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.859735    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.866051    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.872016    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.880550    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.887909    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.895060    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.901843    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.909057    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.917196    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.924593    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784031.939061    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# W0000 00:00:1772784032.961159    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784032.962979    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784032.964701    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784032.966522    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784032.968467    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784032.970322    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784032.972526    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784032.974816    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784032.977288    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784032.980733    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784032.983691    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784032.986892    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784032.990955    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784032.995699    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.003502    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.011786    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.035782    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.039057    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.041009    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.042950    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.045169    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.047687    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.050272    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.053011    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.056062    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.059736    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.063952    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.067627    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.071779    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.075063    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.079040    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.083386    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# W0000 00:00:1772784033.865961    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.868512    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.871127    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.873780    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.876445    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.879700    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.882600    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.886221    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.890956    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.897277    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.904153    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.920134    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.923847    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.926799    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.930279    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.933402    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.936248    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.940357    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.945036    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.950696    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.956642    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.960255    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.967132    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.973284    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.980136    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.986719    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784033.994370    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# W0000 00:00:1772784034.089584    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784034.091058    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784034.092482    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784034.093961    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784034.095623    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784034.097479    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784034.099527    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1772784034.101583    1437 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# ...
# Epoch 45/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1136 - accuracy: 0.9767 - iou_metric: 0.7976
# Epoch 45: val_loss improved from 0.11964 to 0.11585, saving model to project/Poreseg/Model/model_segnetK4.keras
# 149/149 [==============================] - 33s 219ms/step - loss: 0.1136 - accuracy: 0.9767 - iou_metric: 0.7976 - val_loss: 0.1158 - val_accuracy: 0.9764 - val_iou_metric: 0.7939 - lr: 2.5000e-04
# Epoch 46/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1111 - accuracy: 0.9773 - iou_metric: 0.8015
# Epoch 46: val_loss did not improve from 0.11585
# 149/149 [==============================] - 32s 217ms/step - loss: 0.1111 - accuracy: 0.9773 - iou_metric: 0.8015 - val_loss: 0.1161 - val_accuracy: 0.9768 - val_iou_metric: 0.7941 - lr: 2.5000e-04
# Epoch 47/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1104 - accuracy: 0.9774 - iou_metric: 0.8026
# Epoch 47: val_loss improved from 0.11585 to 0.11563, saving model to project/Poreseg/Model/model_segnetK4.keras
# 149/149 [==============================] - 33s 217ms/step - loss: 0.1104 - accuracy: 0.9774 - iou_metric: 0.8026 - val_loss: 0.1156 - val_accuracy: 0.9767 - val_iou_metric: 0.7946 - lr: 2.5000e-04
# Epoch 48/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1107 - accuracy: 0.9773 - iou_metric: 0.8022
# Epoch 48: val_loss did not improve from 0.11563
# 149/149 [==============================] - 32s 216ms/step - loss: 0.1107 - accuracy: 0.9773 - iou_metric: 0.8022 - val_loss: 0.1157 - val_accuracy: 0.9763 - val_iou_metric: 0.7940 - lr: 2.5000e-04
# Epoch 49/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1105 - accuracy: 0.9774 - iou_metric: 0.8027
# Epoch 49: val_loss improved from 0.11563 to 0.11450, saving model to project/Poreseg/Model/model_segnetK4.keras
# 149/149 [==============================] - 33s 218ms/step - loss: 0.1105 - accuracy: 0.9774 - iou_metric: 0.8027 - val_loss: 0.1145 - val_accuracy: 0.9770 - val_iou_metric: 0.7964 - lr: 2.5000e-04
# Epoch 50/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1099 - accuracy: 0.9775 - iou_metric: 0.8034
# Epoch 50: val_loss did not improve from 0.11450
# 149/149 [==============================] - 33s 217ms/step - loss: 0.1099 - accuracy: 0.9775 - iou_metric: 0.8034 - val_loss: 0.1197 - val_accuracy: 0.9766 - val_iou_metric: 0.7893 - lr: 2.5000e-04
# Epoch 51/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1098 - accuracy: 0.9775 - iou_metric: 0.8035
# Epoch 51: val_loss did not improve from 0.11450
# 149/149 [==============================] - 32s 216ms/step - loss: 0.1098 - accuracy: 0.9775 - iou_metric: 0.8035 - val_loss: 0.1162 - val_accuracy: 0.9761 - val_iou_metric: 0.7932 - lr: 2.5000e-04
# Epoch 52/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1090 - accuracy: 0.9777 - iou_metric: 0.8046
# Epoch 52: val_loss did not improve from 0.11450
# 149/149 [==============================] - 32s 216ms/step - loss: 0.1090 - accuracy: 0.9777 - iou_metric: 0.8046 - val_loss: 0.1160 - val_accuracy: 0.9765 - val_iou_metric: 0.7938 - lr: 2.5000e-04
# Epoch 53/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1097 - accuracy: 0.9775 - iou_metric: 0.8037
# Epoch 53: val_loss did not improve from 0.11450
# 149/149 [==============================] - 32s 216ms/step - loss: 0.1097 - accuracy: 0.9775 - iou_metric: 0.8037 - val_loss: 0.1240 - val_accuracy: 0.9738 - val_iou_metric: 0.7807 - lr: 2.5000e-04
# Epoch 54/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1091 - accuracy: 0.9776 - iou_metric: 0.8044
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 54: val_loss did not improve from 0.11450
# 149/149 [==============================] - 32s 216ms/step - loss: 0.1091 - accuracy: 0.9776 - iou_metric: 0.8044 - val_loss: 0.1147 - val_accuracy: 0.9767 - val_iou_metric: 0.7959 - lr: 2.5000e-04
# Epoch 55/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9778 - iou_metric: 0.8057
# Epoch 55: val_loss did not improve from 0.11450
# 149/149 [==============================] - 32s 216ms/step - loss: 0.1085 - accuracy: 0.9778 - iou_metric: 0.8057 - val_loss: 0.1179 - val_accuracy: 0.9769 - val_iou_metric: 0.7920 - lr: 1.2500e-04
# Epoch 56/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.9781 - iou_metric: 0.8080
# Epoch 56: val_loss improved from 0.11450 to 0.11295, saving model to project/Poreseg/Model/model_segnetK4.keras
# 149/149 [==============================] - 33s 218ms/step - loss: 0.1071 - accuracy: 0.9781 - iou_metric: 0.8080 - val_loss: 0.1129 - val_accuracy: 0.9772 - val_iou_metric: 0.7988 - lr: 1.2500e-04
# Epoch 57/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1075 - accuracy: 0.9780 - iou_metric: 0.8075
# Epoch 57: val_loss did not improve from 0.11295
# 149/149 [==============================] - 33s 218ms/step - loss: 0.1075 - accuracy: 0.9780 - iou_metric: 0.8075 - val_loss: 0.1137 - val_accuracy: 0.9772 - val_iou_metric: 0.7979 - lr: 1.2500e-04
# Epoch 58/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.9781 - iou_metric: 0.8079
# Epoch 58: val_loss did not improve from 0.11295
# 149/149 [==============================] - 33s 218ms/step - loss: 0.1071 - accuracy: 0.9781 - iou_metric: 0.8079 - val_loss: 0.1229 - val_accuracy: 0.9762 - val_iou_metric: 0.7846 - lr: 1.2500e-04
# Epoch 59/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1066 - accuracy: 0.9782 - iou_metric: 0.8087
# Epoch 59: val_loss did not improve from 0.11295
# 149/149 [==============================] - 33s 219ms/step - loss: 0.1066 - accuracy: 0.9782 - iou_metric: 0.8087 - val_loss: 0.1144 - val_accuracy: 0.9765 - val_iou_metric: 0.7961 - lr: 1.2500e-04
# Epoch 60/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1070 - accuracy: 0.9782 - iou_metric: 0.8083
# Epoch 60: val_loss did not improve from 0.11295
# 149/149 [==============================] - 33s 219ms/step - loss: 0.1070 - accuracy: 0.9782 - iou_metric: 0.8083 - val_loss: 0.1139 - val_accuracy: 0.9773 - val_iou_metric: 0.7978 - lr: 1.2500e-04
# Epoch 61/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1066 - accuracy: 0.9782 - iou_metric: 0.8087
# Epoch 61: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 61: val_loss did not improve from 0.11295
# 149/149 [==============================] - 33s 219ms/step - loss: 0.1066 - accuracy: 0.9782 - iou_metric: 0.8087 - val_loss: 0.1139 - val_accuracy: 0.9774 - val_iou_metric: 0.7979 - lr: 1.2500e-04
# Epoch 62/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1053 - accuracy: 0.9785 - iou_metric: 0.8109
# Epoch 62: val_loss improved from 0.11295 to 0.11224, saving model to project/Poreseg/Model/model_segnetK4.keras
# 149/149 [==============================] - 33s 220ms/step - loss: 0.1053 - accuracy: 0.9785 - iou_metric: 0.8109 - val_loss: 0.1122 - val_accuracy: 0.9775 - val_iou_metric: 0.8002 - lr: 6.2500e-05
# Epoch 63/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1058 - accuracy: 0.9784 - iou_metric: 0.8103
# Epoch 63: val_loss did not improve from 0.11224
# 149/149 [==============================] - 33s 219ms/step - loss: 0.1058 - accuracy: 0.9784 - iou_metric: 0.8103 - val_loss: 0.1154 - val_accuracy: 0.9771 - val_iou_metric: 0.7956 - lr: 6.2500e-05
# Epoch 64/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1054 - accuracy: 0.9784 - iou_metric: 0.8108
# Epoch 64: val_loss did not improve from 0.11224
# 149/149 [==============================] - 32s 216ms/step - loss: 0.1054 - accuracy: 0.9784 - iou_metric: 0.8108 - val_loss: 0.1133 - val_accuracy: 0.9774 - val_iou_metric: 0.7987 - lr: 6.2500e-05
# Epoch 65/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1054 - accuracy: 0.9785 - iou_metric: 0.8108
# Epoch 65: val_loss did not improve from 0.11224
# 149/149 [==============================] - 32s 215ms/step - loss: 0.1054 - accuracy: 0.9785 - iou_metric: 0.8108 - val_loss: 0.1129 - val_accuracy: 0.9772 - val_iou_metric: 0.7989 - lr: 6.2500e-05
# Epoch 66/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1052 - accuracy: 0.9785 - iou_metric: 0.8112
# Epoch 66: val_loss did not improve from 0.11224
# 149/149 [==============================] - 33s 217ms/step - loss: 0.1052 - accuracy: 0.9785 - iou_metric: 0.8112 - val_loss: 0.1140 - val_accuracy: 0.9773 - val_iou_metric: 0.7977 - lr: 6.2500e-05
# Epoch 67/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1052 - accuracy: 0.9784 - iou_metric: 0.8109
# Epoch 67: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 67: val_loss did not improve from 0.11224
# 149/149 [==============================] - 33s 218ms/step - loss: 0.1052 - accuracy: 0.9784 - iou_metric: 0.8109 - val_loss: 0.1195 - val_accuracy: 0.9767 - val_iou_metric: 0.7897 - lr: 6.2500e-05
# Epoch 68/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1052 - accuracy: 0.9785 - iou_metric: 0.8110
# Epoch 68: val_loss improved from 0.11224 to 0.11193, saving model to project/Poreseg/Model/model_segnetK4.keras
# 149/149 [==============================] - 33s 220ms/step - loss: 0.1052 - accuracy: 0.9785 - iou_metric: 0.8110 - val_loss: 0.1119 - val_accuracy: 0.9772 - val_iou_metric: 0.8002 - lr: 3.1250e-05
# Epoch 69/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1054 - accuracy: 0.9785 - iou_metric: 0.8108
# Epoch 69: val_loss improved from 0.11193 to 0.11142, saving model to project/Poreseg/Model/model_segnetK4.keras
# 149/149 [==============================] - 33s 219ms/step - loss: 0.1054 - accuracy: 0.9785 - iou_metric: 0.8108 - val_loss: 0.1114 - val_accuracy: 0.9775 - val_iou_metric: 0.8012 - lr: 3.1250e-05
# Epoch 70/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9786 - iou_metric: 0.8122
# Epoch 70: val_loss improved from 0.11142 to 0.11123, saving model to project/Poreseg/Model/model_segnetK4.keras
# 149/149 [==============================] - 33s 220ms/step - loss: 0.1046 - accuracy: 0.9786 - iou_metric: 0.8122 - val_loss: 0.1112 - val_accuracy: 0.9775 - val_iou_metric: 0.8015 - lr: 3.1250e-05
# Epoch 71/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9787 - iou_metric: 0.8126
# Epoch 71: val_loss did not improve from 0.11123
# 149/149 [==============================] - 33s 217ms/step - loss: 0.1042 - accuracy: 0.9787 - iou_metric: 0.8126 - val_loss: 0.1114 - val_accuracy: 0.9775 - val_iou_metric: 0.8013 - lr: 3.1250e-05
# Epoch 72/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9786 - iou_metric: 0.8125
# Epoch 72: val_loss did not improve from 0.11123
# 149/149 [==============================] - 32s 217ms/step - loss: 0.1045 - accuracy: 0.9786 - iou_metric: 0.8125 - val_loss: 0.1118 - val_accuracy: 0.9772 - val_iou_metric: 0.8004 - lr: 3.1250e-05
# Epoch 73/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9786 - iou_metric: 0.8118
# Epoch 73: val_loss did not improve from 0.11123
# 149/149 [==============================] - 33s 219ms/step - loss: 0.1049 - accuracy: 0.9786 - iou_metric: 0.8118 - val_loss: 0.1117 - val_accuracy: 0.9773 - val_iou_metric: 0.8006 - lr: 3.1250e-05
# Epoch 74/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9787 - iou_metric: 0.8128
# Epoch 74: val_loss did not improve from 0.11123
# 149/149 [==============================] - 33s 219ms/step - loss: 0.1042 - accuracy: 0.9787 - iou_metric: 0.8128 - val_loss: 0.1118 - val_accuracy: 0.9775 - val_iou_metric: 0.8008 - lr: 3.1250e-05
# Epoch 75/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9787 - iou_metric: 0.8127
# Epoch 75: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 75: val_loss improved from 0.11123 to 0.11118, saving model to project/Poreseg/Model/model_segnetK4.keras
# 149/149 [==============================] - 33s 220ms/step - loss: 0.1042 - accuracy: 0.9787 - iou_metric: 0.8127 - val_loss: 0.1112 - val_accuracy: 0.9775 - val_iou_metric: 0.8015 - lr: 3.1250e-05
# Epoch 76/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9786 - iou_metric: 0.8118
# Epoch 76: val_loss did not improve from 0.11118
# 149/149 [==============================] - 33s 218ms/step - loss: 0.1049 - accuracy: 0.9786 - iou_metric: 0.8118 - val_loss: 0.1126 - val_accuracy: 0.9768 - val_iou_metric: 0.7989 - lr: 1.5625e-05
# Epoch 77/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1047 - accuracy: 0.9786 - iou_metric: 0.8121
# Epoch 77: val_loss did not improve from 0.11118
# 149/149 [==============================] - 32s 215ms/step - loss: 0.1047 - accuracy: 0.9786 - iou_metric: 0.8121 - val_loss: 0.1120 - val_accuracy: 0.9771 - val_iou_metric: 0.8000 - lr: 1.5625e-05
# Epoch 78/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9787 - iou_metric: 0.8126
# Epoch 78: val_loss did not improve from 0.11118
# 149/149 [==============================] - 32s 215ms/step - loss: 0.1045 - accuracy: 0.9787 - iou_metric: 0.8126 - val_loss: 0.1125 - val_accuracy: 0.9769 - val_iou_metric: 0.7991 - lr: 1.5625e-05
# Epoch 79/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.9787 - iou_metric: 0.8127
# Epoch 79: val_loss did not improve from 0.11118
# 149/149 [==============================] - 32s 216ms/step - loss: 0.1044 - accuracy: 0.9787 - iou_metric: 0.8127 - val_loss: 0.1117 - val_accuracy: 0.9771 - val_iou_metric: 0.8004 - lr: 1.5625e-05
# Epoch 80/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9788 - iou_metric: 0.8134
# Epoch 80: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 80: val_loss did not improve from 0.11118
# 149/149 [==============================] - 32s 216ms/step - loss: 0.1040 - accuracy: 0.9788 - iou_metric: 0.8134 - val_loss: 0.1117 - val_accuracy: 0.9771 - val_iou_metric: 0.8004 - lr: 1.5625e-05
# Epoch 81/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1036 - accuracy: 0.9788 - iou_metric: 0.8140
# Epoch 81: val_loss did not improve from 0.11118
# 149/149 [==============================] - 33s 218ms/step - loss: 0.1036 - accuracy: 0.9788 - iou_metric: 0.8140 - val_loss: 0.1125 - val_accuracy: 0.9769 - val_iou_metric: 0.7992 - lr: 7.8125e-06
# Epoch 82/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1041 - accuracy: 0.9787 - iou_metric: 0.8131
# Epoch 82: val_loss did not improve from 0.11118
# 149/149 [==============================] - 33s 219ms/step - loss: 0.1041 - accuracy: 0.9787 - iou_metric: 0.8131 - val_loss: 0.1126 - val_accuracy: 0.9769 - val_iou_metric: 0.7990 - lr: 7.8125e-06
# Epoch 83/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9786 - iou_metric: 0.8125
# Epoch 83: val_loss did not improve from 0.11118
# 149/149 [==============================] - 33s 217ms/step - loss: 0.1045 - accuracy: 0.9786 - iou_metric: 0.8125 - val_loss: 0.1124 - val_accuracy: 0.9769 - val_iou_metric: 0.7993 - lr: 7.8125e-06
# Epoch 84/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1043 - accuracy: 0.9787 - iou_metric: 0.8129
# Epoch 84: val_loss did not improve from 0.11118
# 149/149 [==============================] - 33s 217ms/step - loss: 0.1043 - accuracy: 0.9787 - iou_metric: 0.8129 - val_loss: 0.1128 - val_accuracy: 0.9768 - val_iou_metric: 0.7987 - lr: 7.8125e-06
# Epoch 85/100
# 149/149 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9787 - iou_metric: 0.8132
# Epoch 85: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 85: val_loss did not improve from 0.11118
# 149/149 [==============================] - 33s 217ms/step - loss: 0.1040 - accuracy: 0.9787 - iou_metric: 0.8132 - val_loss: 0.1133 - val_accuracy: 0.9766 - val_iou_metric: 0.7978 - lr: 7.8125e-06

# %%
# Extract data from history.history
epochs = range(1, len(history.history['loss']) + 1)
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
iou = history.history['iou_metric']
val_iou = history.history['val_iou_metric']

# Plotting Training and Validation Accuracy
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.grid(True)
plt.show()  

# Plotting Training and Validation Loss
plt.figure()
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid(True)
plt.show()  # Display loss plot

# Plotting Training and Validation IoU
plt.figure()
plt.plot(epochs, iou, 'r', label='Training IoU')
plt.plot(epochs, val_iou, 'b', label='Validation IoU')
plt.title('Training and validation IoU')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Hitung rata-rata untuk setiap metrik
avg_acc = np.mean(history.history['accuracy'])
avg_val_acc = np.mean(history.history['val_accuracy'])

avg_loss = np.mean(history.history['loss'])
avg_val_loss = np.mean(history.history['val_loss'])

avg_iou = np.mean(history.history['iou_metric'])
avg_val_iou = np.mean(history.history['val_iou_metric'])

# Cetak hasil rata-rata
print("=== Average Results Training ===")
print(f"Average Training Accuracy   : {avg_acc:.4f}")
print(f"Average Validation Accuracy : {avg_val_acc:.4f}")
print(f"Average Training Loss       : {avg_loss:.4f}")
print(f"Average Validation Loss     : {avg_val_loss:.4f}")
print(f"Average Training IoU        : {avg_iou:.4f}")
print(f"Average Validation IoU      : {avg_val_iou:.4f}")
# Out:
# === Average Results Training ===
# Average Training Accuracy   : 0.9743
# Average Validation Accuracy : 0.9705
# Average Training Loss       : 0.1247
# Average Validation Loss     : 0.1634
# Average Training IoU        : 0.7813
# Average Validation IoU      : 0.7417
