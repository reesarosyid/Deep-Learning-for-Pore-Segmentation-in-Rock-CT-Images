# %% [markdown]
# <div style="text-align: center; font-size: 40px; font-weight: bold;">
#     Train Model U-Net Architecture
# </div>

# %% [markdown]
# # Libraries

# %%
import os
import numpy as np
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm
from PIL import Image
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
import tensorflow.keras.backend as K
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from skimage.transform import resize
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
# Out:
# Segmentation Models: using `tf.keras` framework.

# %% [markdown]
# # Functions

# %%
def map_mask_to_classes(mask_array: np.ndarray) -> np.ndarray:
    """
    Maps a binary mask to class labels.
    
    Args:
        mask_array (np.ndarray): Input mask array.
        
    Returns:
        np.ndarray: Binary mask with values mapped to 0 and 1.
    """
    return (mask_array > 0).astype(np.uint8)

# %%
def load_images_and_masks(image_folder: str, mask_folder: str, img_height: int, img_width: int) -> tuple:
    """
    Loads images and masks from specified folders, normalizes images, and processes masks.
    
    Args:
        image_folder (str): Path to the image folder.
        mask_folder (str): Path to the mask folder.
        img_height (int): Target image height.
        img_width (int): Target image width.
        
    Returns:
        tuple: (numpy.ndarray of images, numpy.ndarray of masks)
    """
    images, masks = [], []
    
    image_files = sorted(os.listdir(image_folder))
    mask_files = sorted(os.listdir(mask_folder))
    
    for img_file, mask_file in zip(image_files, mask_files):
        img_path = os.path.join(image_folder, img_file)
        mask_path = os.path.join(mask_folder, mask_file)
        
        # Load and normalize image
        img = load_img(img_path, target_size=(img_height, img_width))
        img = img_to_array(img) / 255.0
        images.append(img)
        
        # Load and process mask
        mask = load_img(mask_path, target_size=(img_height, img_width), color_mode="grayscale")
        mask = img_to_array(mask).astype(np.int32).squeeze()
        masks.append(map_mask_to_classes(mask))
    
    return np.array(images), np.array(masks).reshape(-1, img_height, img_width, 1)

# %%
IMG_HEIGHT, IMG_WIDTH = 512, 512 
def unet_model(input_size: tuple = (IMG_HEIGHT, IMG_WIDTH, 3)) -> Model:
    """
    Builds a U-Net model for image segmentation.
    
    Args:
        input_size (tuple): Shape of the input image.
        
    Returns:
        Model: Compiled U-Net model.
    """
    inputs = Input(input_size)
    
    # Encoder
    def conv_block(x, filters):
        x = Conv2D(filters, (3, 3), activation='relu', padding='same')(x)
        x = Conv2D(filters, (3, 3), activation='relu', padding='same')(x)
        return x
    
    c1 = conv_block(inputs, 16)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = conv_block(p1, 32)
    p2 = MaxPooling2D((2, 2))(c2)
    
    c3 = conv_block(p2, 64)
    p3 = MaxPooling2D((2, 2))(c3)
    
    c4 = conv_block(p3, 128)
    p4 = MaxPooling2D((2, 2))(c4)
    
    # Bottleneck
    c5 = conv_block(p4, 256)
    
    # Decoder
    def upsample_block(x, skip, filters):
        x = Conv2DTranspose(filters, (2, 2), strides=(2, 2), padding='same')(x)
        x = concatenate([x, skip])
        x = conv_block(x, filters)
        return x
    
    c6 = upsample_block(c5, c4, 128)
    c7 = upsample_block(c6, c3, 64)
    c8 = upsample_block(c7, c2, 32)
    c9 = upsample_block(c8, c1, 16)
    
    # Output layer with sigmoid activation
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    
    return Model(inputs, outputs)

# %%
def iou_metric(y_true, y_pred, smooth: float = 1e-6) -> float:
    """
    Computes the Intersection over Union (IoU) metric.
    
    Args:
        y_true: Ground truth binary mask.
        y_pred: Predicted binary mask.
        smooth (float): Smoothing factor to avoid division by zero.
    
    Returns:
        float: IoU score.
    """
    y_pred = K.cast(y_pred > 0.5, dtype='float32')
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred) - intersection
    return (intersection + smooth) / (union + smooth)

# %%
def dice_loss(y_true, y_pred, smooth: float = 1e-6) -> tf.Tensor:
    """
    Computes the Dice loss for image segmentation.
    
    Args:
        y_true: Ground truth binary mask.
        y_pred: Predicted mask.
        smooth (float): Smoothing factor to avoid division by zero.
    
    Returns:
        tf.Tensor: Dice loss value.
    """
    y_true = tf.cast(y_true, tf.float32)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    
    return 1 - ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))

# %% [markdown]
# # Load Images

# %%
# Folder path
folder_path = "Data_mask"

# Sorted images
image_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".bmp")])

# Select the first five images
selected_images = image_files[:5]

# Show images for horizontal structure form
fig, axes = plt.subplots(1, 5, figsize=(15, 5))

# Looping to call the images
for i, img_name in enumerate(selected_images):
    img_path = os.path.join(folder_path, img_name)
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  

    axes[i].imshow(img, cmap="gray")
    axes[i].axis("off")
    axes[i].set_title(f"Sample {i}")

# Plot the images
plt.tight_layout()
plt.show()

# %%
mask_path = "Data_mask/mask_CLAHE_dlm0000.bmp"
mask = Image.open(mask_path)
plt.imshow(mask, cmap='gray')
plt.title("Mask Ground Truth")
plt.axis('off')
plt.show()

# Check unique value on the mask
mask_array = np.array(mask)
print(f"Unique value form masking image: {np.unique(mask_array)}")
# Out:
# Unique value form masking image: [  0 255]

# %% [markdown]
# # Splitting Dataset

# %%
# Load dataset train and validation
train_images, train_masks = load_images_and_masks('Data_split/train/images', 'Data_split/train/masks', IMG_HEIGHT, IMG_WIDTH)
val_images, val_masks = load_images_and_masks('Data_split/valid/images', 'Data_split/valid/masks', IMG_HEIGHT, IMG_WIDTH)

print(f"Shape train_images: {train_images.shape}")
print(f"Shape train_masks: {train_masks.shape}")
# Out:
# Shape train_images: (595, 512, 512, 3)
# Shape train_masks: (595, 512, 512, 1)

# %%
# Buat model
model = unet_model()

# Kompilasi model
# ======= Kompilasi Model =======
model.compile(optimizer='adam',
              loss=dice_loss,
              metrics=['accuracy', iou_metric])

# ======= Callbacks =======
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

lr_reduce = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.5, 
                              patience=5, 
                              min_lr=1e-6,
                              verbose=1)

model_checkpoint = ModelCheckpoint('Model/model_unet.h5', 
                                   monitor='val_loss', 
                                   save_best_only=True, 
                                   verbose=1)

callbacks = [early_stop, lr_reduce, model_checkpoint]
# ======= Training Contoh =======
history = model.fit(train_images, train_masks,
                    validation_data=(val_images, val_masks),
                    epochs=100,
                    callbacks=callbacks)
# Out:
# 2025-09-28 20:32:45.254893: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2025-09-28 20:32:45.255253: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-09-28 20:32:45.255500: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2025-09-28 20:32:45.255693: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-09-28 20:32:45.255837: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/100
# 2025-09-28 20:32:49.238904: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 19/19 [==============================] - ETA: 0s - loss: 0.8350 - accuracy: 0.8526 - iou_metric: 0.3225
# 2025-09-28 20:35:05.085734: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 0.76050, saving model to Model/model.h5
# 19/19 [==============================] - 139s 7s/step - loss: 0.8350 - accuracy: 0.8526 - iou_metric: 0.3225 - val_loss: 0.7605 - val_accuracy: 0.9475 - val_iou_metric: 0.4535 - lr: 0.0010
# Epoch 2/100
# /Users/muhammadreesarosyid/tensorflow-test/env/lib/python3.9/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 19/19 [==============================] - ETA: 0s - loss: 0.6525 - accuracy: 0.8819 - iou_metric: 0.3215
# Epoch 2: val_loss improved from 0.76050 to 0.50424, saving model to Model/model.h5
# 19/19 [==============================] - 141s 7s/step - loss: 0.6525 - accuracy: 0.8819 - iou_metric: 0.3215 - val_loss: 0.5042 - val_accuracy: 0.8996 - val_iou_metric: 0.4472 - lr: 0.0010
# Epoch 3/100
# 19/19 [==============================] - ETA: 0s - loss: 0.3773 - accuracy: 0.9410 - iou_metric: 0.5037
# Epoch 3: val_loss improved from 0.50424 to 0.36180, saving model to Model/model.h5
# 19/19 [==============================] - 149s 8s/step - loss: 0.3773 - accuracy: 0.9410 - iou_metric: 0.5037 - val_loss: 0.3618 - val_accuracy: 0.9485 - val_iou_metric: 0.4812 - lr: 0.0010
# Epoch 4/100
# 19/19 [==============================] - ETA: 0s - loss: 0.3324 - accuracy: 0.9437 - iou_metric: 0.5269
# Epoch 4: val_loss improved from 0.36180 to 0.34335, saving model to Model/model.h5
# 19/19 [==============================] - 152s 8s/step - loss: 0.3324 - accuracy: 0.9437 - iou_metric: 0.5269 - val_loss: 0.3433 - val_accuracy: 0.9510 - val_iou_metric: 0.4984 - lr: 0.0010
# Epoch 5/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2977 - accuracy: 0.9499 - iou_metric: 0.5643
# Epoch 5: val_loss improved from 0.34335 to 0.27355, saving model to Model/model.h5
# 19/19 [==============================] - 163s 9s/step - loss: 0.2977 - accuracy: 0.9499 - iou_metric: 0.5643 - val_loss: 0.2736 - val_accuracy: 0.9498 - val_iou_metric: 0.5984 - lr: 0.0010
# Epoch 6/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2756 - accuracy: 0.9538 - iou_metric: 0.5903
# Epoch 6: val_loss improved from 0.27355 to 0.26414, saving model to Model/model.h5
# 19/19 [==============================] - 191s 10s/step - loss: 0.2756 - accuracy: 0.9538 - iou_metric: 0.5903 - val_loss: 0.2641 - val_accuracy: 0.9501 - val_iou_metric: 0.6092 - lr: 0.0010
# Epoch 7/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2594 - accuracy: 0.9562 - iou_metric: 0.6094
# Epoch 7: val_loss improved from 0.26414 to 0.25037, saving model to Model/model.h5
# 19/19 [==============================] - 171s 9s/step - loss: 0.2594 - accuracy: 0.9562 - iou_metric: 0.6094 - val_loss: 0.2504 - val_accuracy: 0.9611 - val_iou_metric: 0.6162 - lr: 0.0010
# Epoch 8/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 0.9595 - iou_metric: 0.6274
# Epoch 8: val_loss improved from 0.25037 to 0.22226, saving model to Model/model.h5
# 19/19 [==============================] - 163s 8s/step - loss: 0.2445 - accuracy: 0.9595 - iou_metric: 0.6274 - val_loss: 0.2223 - val_accuracy: 0.9618 - val_iou_metric: 0.6600 - lr: 0.0010
# Epoch 9/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2252 - accuracy: 0.9629 - iou_metric: 0.6552
# Epoch 9: val_loss did not improve from 0.22226
# 19/19 [==============================] - 154s 8s/step - loss: 0.2252 - accuracy: 0.9629 - iou_metric: 0.6552 - val_loss: 0.2229 - val_accuracy: 0.9654 - val_iou_metric: 0.6549 - lr: 0.0010
# Epoch 10/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2235 - accuracy: 0.9632 - iou_metric: 0.6556
# Epoch 10: val_loss improved from 0.22226 to 0.20679, saving model to Model/model.h5
# 19/19 [==============================] - 161s 9s/step - loss: 0.2235 - accuracy: 0.9632 - iou_metric: 0.6556 - val_loss: 0.2068 - val_accuracy: 0.9640 - val_iou_metric: 0.6814 - lr: 0.0010
# Epoch 11/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2134 - accuracy: 0.9646 - iou_metric: 0.6694
# Epoch 11: val_loss did not improve from 0.20679
# 19/19 [==============================] - 151s 8s/step - loss: 0.2134 - accuracy: 0.9646 - iou_metric: 0.6694 - val_loss: 0.2126 - val_accuracy: 0.9672 - val_iou_metric: 0.6662 - lr: 0.0010
# Epoch 12/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2043 - accuracy: 0.9663 - iou_metric: 0.6809
# Epoch 12: val_loss improved from 0.20679 to 0.19745, saving model to Model/model.h5
# 19/19 [==============================] - 164s 9s/step - loss: 0.2043 - accuracy: 0.9663 - iou_metric: 0.6809 - val_loss: 0.1975 - val_accuracy: 0.9691 - val_iou_metric: 0.6891 - lr: 0.0010
# Epoch 13/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1996 - accuracy: 0.9673 - iou_metric: 0.6873
# Epoch 13: val_loss improved from 0.19745 to 0.19465, saving model to Model/model.h5
# 19/19 [==============================] - 149s 8s/step - loss: 0.1996 - accuracy: 0.9673 - iou_metric: 0.6873 - val_loss: 0.1947 - val_accuracy: 0.9644 - val_iou_metric: 0.6963 - lr: 0.0010
# Epoch 14/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1856 - accuracy: 0.9695 - iou_metric: 0.7076
# Epoch 14: val_loss improved from 0.19465 to 0.17721, saving model to Model/model.h5
# 19/19 [==============================] - 141s 7s/step - loss: 0.1856 - accuracy: 0.9695 - iou_metric: 0.7076 - val_loss: 0.1772 - val_accuracy: 0.9718 - val_iou_metric: 0.7198 - lr: 0.0010
# Epoch 15/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1788 - accuracy: 0.9710 - iou_metric: 0.7176
# Epoch 15: val_loss improved from 0.17721 to 0.16723, saving model to Model/model.h5
# 19/19 [==============================] - 139s 7s/step - loss: 0.1788 - accuracy: 0.9710 - iou_metric: 0.7176 - val_loss: 0.1672 - val_accuracy: 0.9726 - val_iou_metric: 0.7355 - lr: 0.0010
# Epoch 16/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1744 - accuracy: 0.9715 - iou_metric: 0.7233
# Epoch 16: val_loss improved from 0.16723 to 0.16242, saving model to Model/model.h5
# 19/19 [==============================] - 156s 8s/step - loss: 0.1744 - accuracy: 0.9715 - iou_metric: 0.7233 - val_loss: 0.1624 - val_accuracy: 0.9729 - val_iou_metric: 0.7420 - lr: 0.0010
# Epoch 17/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1661 - accuracy: 0.9730 - iou_metric: 0.7353
# Epoch 17: val_loss improved from 0.16242 to 0.16062, saving model to Model/model.h5
# 19/19 [==============================] - 152s 8s/step - loss: 0.1661 - accuracy: 0.9730 - iou_metric: 0.7353 - val_loss: 0.1606 - val_accuracy: 0.9724 - val_iou_metric: 0.7446 - lr: 0.0010
# Epoch 18/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1678 - accuracy: 0.9724 - iou_metric: 0.7299
# Epoch 18: val_loss improved from 0.16062 to 0.15615, saving model to Model/model.h5
# 19/19 [==============================] - 142s 7s/step - loss: 0.1678 - accuracy: 0.9724 - iou_metric: 0.7299 - val_loss: 0.1561 - val_accuracy: 0.9731 - val_iou_metric: 0.7498 - lr: 0.0010
# Epoch 19/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1608 - accuracy: 0.9737 - iou_metric: 0.7405
# Epoch 19: val_loss did not improve from 0.15615
# 19/19 [==============================] - 143s 7s/step - loss: 0.1608 - accuracy: 0.9737 - iou_metric: 0.7405 - val_loss: 0.1655 - val_accuracy: 0.9696 - val_iou_metric: 0.7346 - lr: 0.0010
# Epoch 20/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1618 - accuracy: 0.9732 - iou_metric: 0.7386
# Epoch 20: val_loss improved from 0.15615 to 0.14654, saving model to Model/model.h5
# 19/19 [==============================] - 136s 7s/step - loss: 0.1618 - accuracy: 0.9732 - iou_metric: 0.7386 - val_loss: 0.1465 - val_accuracy: 0.9755 - val_iou_metric: 0.7627 - lr: 0.0010
# Epoch 21/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1526 - accuracy: 0.9750 - iou_metric: 0.7526
# Epoch 21: val_loss did not improve from 0.14654
# 19/19 [==============================] - 144s 7s/step - loss: 0.1526 - accuracy: 0.9750 - iou_metric: 0.7526 - val_loss: 0.1473 - val_accuracy: 0.9764 - val_iou_metric: 0.7590 - lr: 0.0010
# Epoch 22/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1537 - accuracy: 0.9746 - iou_metric: 0.7494
# Epoch 22: val_loss did not improve from 0.14654
# 19/19 [==============================] - 130s 7s/step - loss: 0.1537 - accuracy: 0.9746 - iou_metric: 0.7494 - val_loss: 0.1707 - val_accuracy: 0.9735 - val_iou_metric: 0.7181 - lr: 0.0010
# Epoch 23/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1573 - accuracy: 0.9738 - iou_metric: 0.7426
# Epoch 23: val_loss did not improve from 0.14654
# 19/19 [==============================] - 410s 22s/step - loss: 0.1573 - accuracy: 0.9738 - iou_metric: 0.7426 - val_loss: 0.1522 - val_accuracy: 0.9759 - val_iou_metric: 0.7478 - lr: 0.0010
# Epoch 24/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1548 - accuracy: 0.9743 - iou_metric: 0.7453
# Epoch 24: val_loss improved from 0.14654 to 0.13599, saving model to Model/model.h5
# 19/19 [==============================] - 148s 8s/step - loss: 0.1548 - accuracy: 0.9743 - iou_metric: 0.7453 - val_loss: 0.1360 - val_accuracy: 0.9766 - val_iou_metric: 0.7770 - lr: 0.0010
# Epoch 25/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9762 - iou_metric: 0.7653
# Epoch 25: val_loss did not improve from 0.13599
# 19/19 [==============================] - 148s 8s/step - loss: 0.1426 - accuracy: 0.9762 - iou_metric: 0.7653 - val_loss: 0.1409 - val_accuracy: 0.9775 - val_iou_metric: 0.7657 - lr: 0.0010
# Epoch 26/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1382 - accuracy: 0.9773 - iou_metric: 0.7711
# Epoch 26: val_loss improved from 0.13599 to 0.12867, saving model to Model/model.h5
# 19/19 [==============================] - 135s 7s/step - loss: 0.1382 - accuracy: 0.9773 - iou_metric: 0.7711 - val_loss: 0.1287 - val_accuracy: 0.9790 - val_iou_metric: 0.7866 - lr: 0.0010
# Epoch 27/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9783 - iou_metric: 0.7813
# Epoch 27: val_loss improved from 0.12867 to 0.12538, saving model to Model/model.h5
# 19/19 [==============================] - 145s 7s/step - loss: 0.1320 - accuracy: 0.9783 - iou_metric: 0.7813 - val_loss: 0.1254 - val_accuracy: 0.9795 - val_iou_metric: 0.7914 - lr: 0.0010
# Epoch 28/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1307 - accuracy: 0.9785 - iou_metric: 0.7831
# Epoch 28: val_loss improved from 0.12538 to 0.12225, saving model to Model/model.h5
# 19/19 [==============================] - 134s 7s/step - loss: 0.1307 - accuracy: 0.9785 - iou_metric: 0.7831 - val_loss: 0.1223 - val_accuracy: 0.9791 - val_iou_metric: 0.7974 - lr: 0.0010
# Epoch 29/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1317 - accuracy: 0.9782 - iou_metric: 0.7801
# Epoch 29: val_loss improved from 0.12225 to 0.12000, saving model to Model/model.h5
# 19/19 [==============================] - 131s 7s/step - loss: 0.1317 - accuracy: 0.9782 - iou_metric: 0.7801 - val_loss: 0.1200 - val_accuracy: 0.9800 - val_iou_metric: 0.7991 - lr: 0.0010
# Epoch 30/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1259 - accuracy: 0.9792 - iou_metric: 0.7894
# Epoch 30: val_loss did not improve from 0.12000
# 19/19 [==============================] - 138s 7s/step - loss: 0.1259 - accuracy: 0.9792 - iou_metric: 0.7894 - val_loss: 0.1208 - val_accuracy: 0.9803 - val_iou_metric: 0.7968 - lr: 0.0010
# Epoch 31/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.9798 - iou_metric: 0.7952
# Epoch 31: val_loss improved from 0.12000 to 0.11364, saving model to Model/model.h5
# 19/19 [==============================] - 138s 7s/step - loss: 0.1220 - accuracy: 0.9798 - iou_metric: 0.7952 - val_loss: 0.1136 - val_accuracy: 0.9812 - val_iou_metric: 0.8087 - lr: 0.0010
# Epoch 32/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1259 - accuracy: 0.9790 - iou_metric: 0.7876
# Epoch 32: val_loss did not improve from 0.11364
# 19/19 [==============================] - 141s 7s/step - loss: 0.1259 - accuracy: 0.9790 - iou_metric: 0.7876 - val_loss: 0.1144 - val_accuracy: 0.9801 - val_iou_metric: 0.8072 - lr: 0.0010
# Epoch 33/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1182 - accuracy: 0.9803 - iou_metric: 0.8000
# Epoch 33: val_loss improved from 0.11364 to 0.11324, saving model to Model/model.h5
# 19/19 [==============================] - 133s 7s/step - loss: 0.1182 - accuracy: 0.9803 - iou_metric: 0.8000 - val_loss: 0.1132 - val_accuracy: 0.9814 - val_iou_metric: 0.8072 - lr: 0.0010
# Epoch 34/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.9806 - iou_metric: 0.8026
# Epoch 34: val_loss improved from 0.11324 to 0.11275, saving model to Model/model.h5
# 19/19 [==============================] - 139s 7s/step - loss: 0.1167 - accuracy: 0.9806 - iou_metric: 0.8026 - val_loss: 0.1127 - val_accuracy: 0.9802 - val_iou_metric: 0.8089 - lr: 0.0010
# Epoch 35/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1186 - accuracy: 0.9800 - iou_metric: 0.7981
# Epoch 35: val_loss improved from 0.11275 to 0.11204, saving model to Model/model.h5
# 19/19 [==============================] - 148s 8s/step - loss: 0.1186 - accuracy: 0.9800 - iou_metric: 0.7981 - val_loss: 0.1120 - val_accuracy: 0.9816 - val_iou_metric: 0.8082 - lr: 0.0010
# Epoch 36/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1127 - accuracy: 0.9813 - iou_metric: 0.8083
# Epoch 36: val_loss did not improve from 0.11204
# 19/19 [==============================] - 142s 7s/step - loss: 0.1127 - accuracy: 0.9813 - iou_metric: 0.8083 - val_loss: 0.1163 - val_accuracy: 0.9810 - val_iou_metric: 0.8001 - lr: 0.0010
# Epoch 37/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1104 - accuracy: 0.9817 - iou_metric: 0.8109
# Epoch 37: val_loss improved from 0.11204 to 0.10235, saving model to Model/model.h5
# 19/19 [==============================] - 141s 7s/step - loss: 0.1104 - accuracy: 0.9817 - iou_metric: 0.8109 - val_loss: 0.1023 - val_accuracy: 0.9829 - val_iou_metric: 0.8250 - lr: 0.0010
# Epoch 38/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1095 - accuracy: 0.9818 - iou_metric: 0.8125
# Epoch 38: val_loss did not improve from 0.10235
# 19/19 [==============================] - 173s 9s/step - loss: 0.1095 - accuracy: 0.9818 - iou_metric: 0.8125 - val_loss: 0.1029 - val_accuracy: 0.9824 - val_iou_metric: 0.8240 - lr: 0.0010
# Epoch 39/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1110 - accuracy: 0.9814 - iou_metric: 0.8092
# Epoch 39: val_loss did not improve from 0.10235
# 19/19 [==============================] - 143s 7s/step - loss: 0.1110 - accuracy: 0.9814 - iou_metric: 0.8092 - val_loss: 0.1147 - val_accuracy: 0.9813 - val_iou_metric: 0.8019 - lr: 0.0010
# Epoch 40/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1143 - accuracy: 0.9808 - iou_metric: 0.8036
# Epoch 40: val_loss did not improve from 0.10235
# 19/19 [==============================] - 151s 8s/step - loss: 0.1143 - accuracy: 0.9808 - iou_metric: 0.8036 - val_loss: 0.1067 - val_accuracy: 0.9824 - val_iou_metric: 0.8161 - lr: 0.0010
# Epoch 41/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1103 - accuracy: 0.9815 - iou_metric: 0.8109
# Epoch 41: val_loss improved from 0.10235 to 0.09971, saving model to Model/model.h5
# 19/19 [==============================] - 137s 7s/step - loss: 0.1103 - accuracy: 0.9815 - iou_metric: 0.8109 - val_loss: 0.0997 - val_accuracy: 0.9832 - val_iou_metric: 0.8286 - lr: 0.0010
# Epoch 42/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1043 - accuracy: 0.9826 - iou_metric: 0.8199
# Epoch 42: val_loss improved from 0.09971 to 0.09720, saving model to Model/model.h5
# 19/19 [==============================] - 145s 7s/step - loss: 0.1043 - accuracy: 0.9826 - iou_metric: 0.8199 - val_loss: 0.0972 - val_accuracy: 0.9837 - val_iou_metric: 0.8324 - lr: 0.0010
# Epoch 43/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9826 - iou_metric: 0.8200
# Epoch 43: val_loss did not improve from 0.09720
# 19/19 [==============================] - 133s 7s/step - loss: 0.1045 - accuracy: 0.9826 - iou_metric: 0.8200 - val_loss: 0.1046 - val_accuracy: 0.9813 - val_iou_metric: 0.8195 - lr: 0.0010
# Epoch 44/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9830 - iou_metric: 0.8247
# Epoch 44: val_loss did not improve from 0.09720
# 19/19 [==============================] - 133s 7s/step - loss: 0.1016 - accuracy: 0.9830 - iou_metric: 0.8247 - val_loss: 0.0981 - val_accuracy: 0.9837 - val_iou_metric: 0.8298 - lr: 0.0010
# Epoch 45/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0970 - accuracy: 0.9839 - iou_metric: 0.8322
# Epoch 45: val_loss did not improve from 0.09720
# 19/19 [==============================] - 125s 7s/step - loss: 0.0970 - accuracy: 0.9839 - iou_metric: 0.8322 - val_loss: 0.0987 - val_accuracy: 0.9837 - val_iou_metric: 0.8282 - lr: 0.0010
# Epoch 46/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0948 - accuracy: 0.9843 - iou_metric: 0.8352
# Epoch 46: val_loss improved from 0.09720 to 0.09380, saving model to Model/model.h5
# 19/19 [==============================] - 137s 7s/step - loss: 0.0948 - accuracy: 0.9843 - iou_metric: 0.8352 - val_loss: 0.0938 - val_accuracy: 0.9840 - val_iou_metric: 0.8376 - lr: 0.0010
# Epoch 47/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0935 - accuracy: 0.9844 - iou_metric: 0.8372
# Epoch 47: val_loss did not improve from 0.09380
# 19/19 [==============================] - 124s 6s/step - loss: 0.0935 - accuracy: 0.9844 - iou_metric: 0.8372 - val_loss: 0.1224 - val_accuracy: 0.9803 - val_iou_metric: 0.7864 - lr: 0.0010
# Epoch 48/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9817 - iou_metric: 0.8128
# Epoch 48: val_loss did not improve from 0.09380
# 19/19 [==============================] - 147s 8s/step - loss: 0.1082 - accuracy: 0.9817 - iou_metric: 0.8128 - val_loss: 0.0960 - val_accuracy: 0.9837 - val_iou_metric: 0.8328 - lr: 0.0010
# Epoch 49/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0977 - accuracy: 0.9837 - iou_metric: 0.8307
# Epoch 49: val_loss improved from 0.09380 to 0.09311, saving model to Model/model.h5
# 19/19 [==============================] - 134s 7s/step - loss: 0.0977 - accuracy: 0.9837 - iou_metric: 0.8307 - val_loss: 0.0931 - val_accuracy: 0.9837 - val_iou_metric: 0.8384 - lr: 0.0010
# Epoch 50/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0943 - accuracy: 0.9843 - iou_metric: 0.8366
# Epoch 50: val_loss did not improve from 0.09311
# 19/19 [==============================] - 151s 8s/step - loss: 0.0943 - accuracy: 0.9843 - iou_metric: 0.8366 - val_loss: 0.0939 - val_accuracy: 0.9834 - val_iou_metric: 0.8370 - lr: 0.0010
# Epoch 51/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.9844 - iou_metric: 0.8370
# Epoch 51: val_loss improved from 0.09311 to 0.08840, saving model to Model/model.h5
# 19/19 [==============================] - 161s 9s/step - loss: 0.0933 - accuracy: 0.9844 - iou_metric: 0.8370 - val_loss: 0.0884 - val_accuracy: 0.9847 - val_iou_metric: 0.8462 - lr: 0.0010
# Epoch 52/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0894 - accuracy: 0.9851 - iou_metric: 0.8439
# Epoch 52: val_loss improved from 0.08840 to 0.08555, saving model to Model/model.h5
# 19/19 [==============================] - 137s 7s/step - loss: 0.0894 - accuracy: 0.9851 - iou_metric: 0.8439 - val_loss: 0.0855 - val_accuracy: 0.9856 - val_iou_metric: 0.8505 - lr: 0.0010
# Epoch 53/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0850 - accuracy: 0.9859 - iou_metric: 0.8521
# Epoch 53: val_loss improved from 0.08555 to 0.08184, saving model to Model/model.h5
# 19/19 [==============================] - 129s 7s/step - loss: 0.0850 - accuracy: 0.9859 - iou_metric: 0.8521 - val_loss: 0.0818 - val_accuracy: 0.9862 - val_iou_metric: 0.8573 - lr: 0.0010
# Epoch 54/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9860 - iou_metric: 0.8526
# Epoch 54: val_loss improved from 0.08184 to 0.08129, saving model to Model/model.h5
# 19/19 [==============================] - 134s 7s/step - loss: 0.0845 - accuracy: 0.9860 - iou_metric: 0.8526 - val_loss: 0.0813 - val_accuracy: 0.9864 - val_iou_metric: 0.8578 - lr: 0.0010
# Epoch 55/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0821 - accuracy: 0.9864 - iou_metric: 0.8565
# Epoch 55: val_loss did not improve from 0.08129
# 19/19 [==============================] - 134s 7s/step - loss: 0.0821 - accuracy: 0.9864 - iou_metric: 0.8565 - val_loss: 0.0834 - val_accuracy: 0.9863 - val_iou_metric: 0.8536 - lr: 0.0010
# Epoch 56/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0802 - accuracy: 0.9868 - iou_metric: 0.8598
# Epoch 56: val_loss improved from 0.08129 to 0.08067, saving model to Model/model.h5
# 19/19 [==============================] - 123s 6s/step - loss: 0.0802 - accuracy: 0.9868 - iou_metric: 0.8598 - val_loss: 0.0807 - val_accuracy: 0.9861 - val_iou_metric: 0.8591 - lr: 0.0010
# Epoch 57/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9868 - iou_metric: 0.8606
# Epoch 57: val_loss improved from 0.08067 to 0.07920, saving model to Model/model.h5
# 19/19 [==============================] - 130s 7s/step - loss: 0.0795 - accuracy: 0.9868 - iou_metric: 0.8606 - val_loss: 0.0792 - val_accuracy: 0.9868 - val_iou_metric: 0.8609 - lr: 0.0010
# Epoch 58/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0771 - accuracy: 0.9873 - iou_metric: 0.8651
# Epoch 58: val_loss improved from 0.07920 to 0.07669, saving model to Model/model.h5
# 19/19 [==============================] - 121s 6s/step - loss: 0.0771 - accuracy: 0.9873 - iou_metric: 0.8651 - val_loss: 0.0767 - val_accuracy: 0.9873 - val_iou_metric: 0.8652 - lr: 0.0010
# Epoch 59/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9873 - iou_metric: 0.8656
# Epoch 59: val_loss improved from 0.07669 to 0.07489, saving model to Model/model.h5
# 19/19 [==============================] - 131s 7s/step - loss: 0.0767 - accuracy: 0.9873 - iou_metric: 0.8656 - val_loss: 0.0749 - val_accuracy: 0.9873 - val_iou_metric: 0.8687 - lr: 0.0010
# Epoch 60/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9875 - iou_metric: 0.8673
# Epoch 60: val_loss did not improve from 0.07489
# 19/19 [==============================] - 126s 6s/step - loss: 0.0758 - accuracy: 0.9875 - iou_metric: 0.8673 - val_loss: 0.0816 - val_accuracy: 0.9856 - val_iou_metric: 0.8563 - lr: 0.0010
# Epoch 61/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9874 - iou_metric: 0.8669
# Epoch 61: val_loss improved from 0.07489 to 0.07368, saving model to Model/model.h5
# 19/19 [==============================] - 164s 9s/step - loss: 0.0760 - accuracy: 0.9874 - iou_metric: 0.8669 - val_loss: 0.0737 - val_accuracy: 0.9877 - val_iou_metric: 0.8705 - lr: 0.0010
# Epoch 62/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9880 - iou_metric: 0.8722
# Epoch 62: val_loss improved from 0.07368 to 0.07194, saving model to Model/model.h5
# 19/19 [==============================] - 1129s 62s/step - loss: 0.0728 - accuracy: 0.9880 - iou_metric: 0.8722 - val_loss: 0.0719 - val_accuracy: 0.9879 - val_iou_metric: 0.8738 - lr: 0.0010
# Epoch 63/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0689 - accuracy: 0.9887 - iou_metric: 0.8794
# Epoch 63: val_loss did not improve from 0.07194
# 19/19 [==============================] - 122s 6s/step - loss: 0.0689 - accuracy: 0.9887 - iou_metric: 0.8794 - val_loss: 0.0762 - val_accuracy: 0.9875 - val_iou_metric: 0.8652 - lr: 0.0010
# Epoch 64/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0705 - accuracy: 0.9884 - iou_metric: 0.8762
# Epoch 64: val_loss did not improve from 0.07194
# 19/19 [==============================] - 121s 6s/step - loss: 0.0705 - accuracy: 0.9884 - iou_metric: 0.8762 - val_loss: 0.0725 - val_accuracy: 0.9880 - val_iou_metric: 0.8719 - lr: 0.0010
# Epoch 65/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0697 - accuracy: 0.9886 - iou_metric: 0.8774
# Epoch 65: val_loss did not improve from 0.07194
# 19/19 [==============================] - 117s 6s/step - loss: 0.0697 - accuracy: 0.9886 - iou_metric: 0.8774 - val_loss: 0.0727 - val_accuracy: 0.9874 - val_iou_metric: 0.8721 - lr: 0.0010
# Epoch 66/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0676 - accuracy: 0.9889 - iou_metric: 0.8814
# Epoch 66: val_loss improved from 0.07194 to 0.06790, saving model to Model/model.h5
# 19/19 [==============================] - 114s 6s/step - loss: 0.0676 - accuracy: 0.9889 - iou_metric: 0.8814 - val_loss: 0.0679 - val_accuracy: 0.9887 - val_iou_metric: 0.8806 - lr: 0.0010
# Epoch 67/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0660 - accuracy: 0.9892 - iou_metric: 0.8838
# Epoch 67: val_loss improved from 0.06790 to 0.06734, saving model to Model/model.h5
# 19/19 [==============================] - 127s 7s/step - loss: 0.0660 - accuracy: 0.9892 - iou_metric: 0.8838 - val_loss: 0.0673 - val_accuracy: 0.9886 - val_iou_metric: 0.8816 - lr: 0.0010
# Epoch 68/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0689 - accuracy: 0.9886 - iou_metric: 0.8779
# Epoch 68: val_loss improved from 0.06734 to 0.06726, saving model to Model/model.h5
# 19/19 [==============================] - 119s 6s/step - loss: 0.0689 - accuracy: 0.9886 - iou_metric: 0.8779 - val_loss: 0.0673 - val_accuracy: 0.9886 - val_iou_metric: 0.8816 - lr: 0.0010
# Epoch 69/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9890 - iou_metric: 0.8823
# Epoch 69: val_loss improved from 0.06726 to 0.06564, saving model to Model/model.h5
# 19/19 [==============================] - 135s 7s/step - loss: 0.0668 - accuracy: 0.9890 - iou_metric: 0.8823 - val_loss: 0.0656 - val_accuracy: 0.9889 - val_iou_metric: 0.8845 - lr: 0.0010
# Epoch 70/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.9897 - iou_metric: 0.8894
# Epoch 70: val_loss improved from 0.06564 to 0.06501, saving model to Model/model.h5
# 19/19 [==============================] - 124s 6s/step - loss: 0.0628 - accuracy: 0.9897 - iou_metric: 0.8894 - val_loss: 0.0650 - val_accuracy: 0.9892 - val_iou_metric: 0.8855 - lr: 0.0010
# Epoch 71/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9896 - iou_metric: 0.8880
# Epoch 71: val_loss did not improve from 0.06501
# 19/19 [==============================] - 126s 7s/step - loss: 0.0636 - accuracy: 0.9896 - iou_metric: 0.8880 - val_loss: 0.0678 - val_accuracy: 0.9887 - val_iou_metric: 0.8799 - lr: 0.0010
# Epoch 72/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9898 - iou_metric: 0.8905
# Epoch 72: val_loss did not improve from 0.06501
# 19/19 [==============================] - 133s 7s/step - loss: 0.0621 - accuracy: 0.9898 - iou_metric: 0.8905 - val_loss: 0.0662 - val_accuracy: 0.9890 - val_iou_metric: 0.8826 - lr: 0.0010
# Epoch 73/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0626 - accuracy: 0.9897 - iou_metric: 0.8892
# Epoch 73: val_loss improved from 0.06501 to 0.06430, saving model to Model/model.h5
# 19/19 [==============================] - 124s 6s/step - loss: 0.0626 - accuracy: 0.9897 - iou_metric: 0.8892 - val_loss: 0.0643 - val_accuracy: 0.9892 - val_iou_metric: 0.8863 - lr: 0.0010
# Epoch 74/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 0.9904 - iou_metric: 0.8962
# Epoch 74: val_loss did not improve from 0.06430
# 19/19 [==============================] - 123s 6s/step - loss: 0.0591 - accuracy: 0.9904 - iou_metric: 0.8962 - val_loss: 0.0645 - val_accuracy: 0.9889 - val_iou_metric: 0.8857 - lr: 0.0010
# Epoch 75/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0585 - accuracy: 0.9905 - iou_metric: 0.8967
# Epoch 75: val_loss did not improve from 0.06430
# 19/19 [==============================] - 127s 7s/step - loss: 0.0585 - accuracy: 0.9905 - iou_metric: 0.8967 - val_loss: 0.0647 - val_accuracy: 0.9893 - val_iou_metric: 0.8851 - lr: 0.0010
# Epoch 76/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0571 - accuracy: 0.9907 - iou_metric: 0.8995
# Epoch 76: val_loss improved from 0.06430 to 0.06183, saving model to Model/model.h5
# 19/19 [==============================] - 133s 7s/step - loss: 0.0571 - accuracy: 0.9907 - iou_metric: 0.8995 - val_loss: 0.0618 - val_accuracy: 0.9898 - val_iou_metric: 0.8903 - lr: 0.0010
# Epoch 77/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9901 - iou_metric: 0.8935
# Epoch 77: val_loss did not improve from 0.06183
# 19/19 [==============================] - 122s 6s/step - loss: 0.0602 - accuracy: 0.9901 - iou_metric: 0.8935 - val_loss: 0.0652 - val_accuracy: 0.9887 - val_iou_metric: 0.8842 - lr: 0.0010
# Epoch 78/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0601 - accuracy: 0.9901 - iou_metric: 0.8935
# Epoch 78: val_loss did not improve from 0.06183
# 19/19 [==============================] - 123s 6s/step - loss: 0.0601 - accuracy: 0.9901 - iou_metric: 0.8935 - val_loss: 0.0629 - val_accuracy: 0.9896 - val_iou_metric: 0.8879 - lr: 0.0010
# Epoch 79/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0557 - accuracy: 0.9909 - iou_metric: 0.9020
# Epoch 79: val_loss improved from 0.06183 to 0.05905, saving model to Model/model.h5
# 19/19 [==============================] - 127s 7s/step - loss: 0.0557 - accuracy: 0.9909 - iou_metric: 0.9020 - val_loss: 0.0590 - val_accuracy: 0.9901 - val_iou_metric: 0.8955 - lr: 0.0010
# Epoch 80/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9910 - iou_metric: 0.9021
# Epoch 80: val_loss improved from 0.05905 to 0.05801, saving model to Model/model.h5
# 19/19 [==============================] - 130s 7s/step - loss: 0.0555 - accuracy: 0.9910 - iou_metric: 0.9021 - val_loss: 0.0580 - val_accuracy: 0.9904 - val_iou_metric: 0.8972 - lr: 0.0010
# Epoch 81/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0522 - accuracy: 0.9916 - iou_metric: 0.9083
# Epoch 81: val_loss did not improve from 0.05801
# 19/19 [==============================] - 123s 6s/step - loss: 0.0522 - accuracy: 0.9916 - iou_metric: 0.9083 - val_loss: 0.0580 - val_accuracy: 0.9904 - val_iou_metric: 0.8970 - lr: 0.0010
# Epoch 82/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0526 - accuracy: 0.9915 - iou_metric: 0.9073
# Epoch 82: val_loss improved from 0.05801 to 0.05694, saving model to Model/model.h5
# 19/19 [==============================] - 123s 6s/step - loss: 0.0526 - accuracy: 0.9915 - iou_metric: 0.9073 - val_loss: 0.0569 - val_accuracy: 0.9905 - val_iou_metric: 0.8991 - lr: 0.0010
# Epoch 83/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9913 - iou_metric: 0.9058
# Epoch 83: val_loss did not improve from 0.05694
# 19/19 [==============================] - 125s 7s/step - loss: 0.0534 - accuracy: 0.9913 - iou_metric: 0.9058 - val_loss: 0.0589 - val_accuracy: 0.9899 - val_iou_metric: 0.8952 - lr: 0.0010
# Epoch 84/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9918 - iou_metric: 0.9108
# Epoch 84: val_loss did not improve from 0.05694
# 19/19 [==============================] - 116s 6s/step - loss: 0.0506 - accuracy: 0.9918 - iou_metric: 0.9108 - val_loss: 0.0628 - val_accuracy: 0.9897 - val_iou_metric: 0.8877 - lr: 0.0010
# Epoch 85/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0516 - accuracy: 0.9916 - iou_metric: 0.9092
# Epoch 85: val_loss did not improve from 0.05694
# 19/19 [==============================] - 118s 6s/step - loss: 0.0516 - accuracy: 0.9916 - iou_metric: 0.9092 - val_loss: 0.0572 - val_accuracy: 0.9903 - val_iou_metric: 0.8983 - lr: 0.0010
# Epoch 86/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 0.9920 - iou_metric: 0.9125
# Epoch 86: val_loss improved from 0.05694 to 0.05554, saving model to Model/model.h5
# 19/19 [==============================] - 120s 6s/step - loss: 0.0497 - accuracy: 0.9920 - iou_metric: 0.9125 - val_loss: 0.0555 - val_accuracy: 0.9906 - val_iou_metric: 0.9012 - lr: 0.0010
# Epoch 87/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0490 - accuracy: 0.9921 - iou_metric: 0.9140
# Epoch 87: val_loss did not improve from 0.05554
# 19/19 [==============================] - 120s 6s/step - loss: 0.0490 - accuracy: 0.9921 - iou_metric: 0.9140 - val_loss: 0.0561 - val_accuracy: 0.9905 - val_iou_metric: 0.9003 - lr: 0.0010
# Epoch 88/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9921 - iou_metric: 0.9141
# Epoch 88: val_loss improved from 0.05554 to 0.05482, saving model to Model/model.h5
# 19/19 [==============================] - 122s 6s/step - loss: 0.0488 - accuracy: 0.9921 - iou_metric: 0.9141 - val_loss: 0.0548 - val_accuracy: 0.9909 - val_iou_metric: 0.9026 - lr: 0.0010
# Epoch 89/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0533 - accuracy: 0.9912 - iou_metric: 0.9051
# Epoch 89: val_loss did not improve from 0.05482
# 19/19 [==============================] - 118s 6s/step - loss: 0.0533 - accuracy: 0.9912 - iou_metric: 0.9051 - val_loss: 0.0564 - val_accuracy: 0.9906 - val_iou_metric: 0.8994 - lr: 0.0010
# Epoch 90/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9911 - iou_metric: 0.9039
# Epoch 90: val_loss did not improve from 0.05482
# 19/19 [==============================] - 121s 6s/step - loss: 0.0541 - accuracy: 0.9911 - iou_metric: 0.9039 - val_loss: 0.0599 - val_accuracy: 0.9901 - val_iou_metric: 0.8924 - lr: 0.0010
# Epoch 91/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9921 - iou_metric: 0.9139
# Epoch 91: val_loss did not improve from 0.05482
# 19/19 [==============================] - 125s 6s/step - loss: 0.0488 - accuracy: 0.9921 - iou_metric: 0.9139 - val_loss: 0.0550 - val_accuracy: 0.9908 - val_iou_metric: 0.9018 - lr: 0.0010
# Epoch 92/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9924 - iou_metric: 0.9175
# Epoch 92: val_loss did not improve from 0.05482
# 19/19 [==============================] - 117s 6s/step - loss: 0.0469 - accuracy: 0.9924 - iou_metric: 0.9175 - val_loss: 0.0579 - val_accuracy: 0.9905 - val_iou_metric: 0.8960 - lr: 0.0010
# Epoch 93/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.9925 - iou_metric: 0.9180
# Epoch 93: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 93: val_loss did not improve from 0.05482
# 19/19 [==============================] - 121s 6s/step - loss: 0.0464 - accuracy: 0.9925 - iou_metric: 0.9180 - val_loss: 0.0558 - val_accuracy: 0.9908 - val_iou_metric: 0.9002 - lr: 0.0010
# Epoch 94/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0457 - accuracy: 0.9927 - iou_metric: 0.9196
# Epoch 94: val_loss improved from 0.05482 to 0.05268, saving model to Model/model.h5
# 19/19 [==============================] - 124s 7s/step - loss: 0.0457 - accuracy: 0.9927 - iou_metric: 0.9196 - val_loss: 0.0527 - val_accuracy: 0.9912 - val_iou_metric: 0.9059 - lr: 5.0000e-04
# Epoch 95/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 0.9930 - iou_metric: 0.9227
# Epoch 95: val_loss did not improve from 0.05268
# 19/19 [==============================] - 127s 7s/step - loss: 0.0441 - accuracy: 0.9930 - iou_metric: 0.9227 - val_loss: 0.0557 - val_accuracy: 0.9908 - val_iou_metric: 0.9002 - lr: 5.0000e-04
# Epoch 96/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9932 - iou_metric: 0.9251
# Epoch 96: val_loss improved from 0.05268 to 0.05259, saving model to Model/model.h5
# 19/19 [==============================] - 119s 6s/step - loss: 0.0430 - accuracy: 0.9932 - iou_metric: 0.9251 - val_loss: 0.0526 - val_accuracy: 0.9912 - val_iou_metric: 0.9062 - lr: 5.0000e-04
# Epoch 97/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0433 - accuracy: 0.9931 - iou_metric: 0.9243
# Epoch 97: val_loss did not improve from 0.05259
# 19/19 [==============================] - 125s 7s/step - loss: 0.0433 - accuracy: 0.9931 - iou_metric: 0.9243 - val_loss: 0.0529 - val_accuracy: 0.9912 - val_iou_metric: 0.9055 - lr: 5.0000e-04
# Epoch 98/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0427 - accuracy: 0.9932 - iou_metric: 0.9255
# Epoch 98: val_loss improved from 0.05259 to 0.05239, saving model to Model/model.h5
# 19/19 [==============================] - 116s 6s/step - loss: 0.0427 - accuracy: 0.9932 - iou_metric: 0.9255 - val_loss: 0.0524 - val_accuracy: 0.9912 - val_iou_metric: 0.9065 - lr: 5.0000e-04
# Epoch 99/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0422 - accuracy: 0.9933 - iou_metric: 0.9264
# Epoch 99: val_loss did not improve from 0.05239
# 19/19 [==============================] - 121s 6s/step - loss: 0.0422 - accuracy: 0.9933 - iou_metric: 0.9264 - val_loss: 0.0544 - val_accuracy: 0.9910 - val_iou_metric: 0.9023 - lr: 5.0000e-04
# Epoch 100/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.9934 - iou_metric: 0.9270
# Epoch 100: val_loss improved from 0.05239 to 0.05207, saving model to Model/model.h5
# 19/19 [==============================] - 119s 6s/step - loss: 0.0419 - accuracy: 0.9934 - iou_metric: 0.9270 - val_loss: 0.0521 - val_accuracy: 0.9913 - val_iou_metric: 0.9069 - lr: 5.0000e-04

# %%
# Extract data from history.history
epochs = range(1, len(history.history['loss']) + 1)
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
iou = history.history['iou_metric']
val_iou = history.history['val_iou_metric']

# Plotting Training and Validation Accuracy
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.grid(True)
plt.show()  # Display accuracy plot

# Plotting Training and Validation Loss
plt.figure()
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid(True)
plt.show()  # Display loss plot

# Plotting Training and Validation IoU
plt.figure()
plt.plot(epochs, iou, 'r', label='Training IoU')
plt.plot(epochs, val_iou, 'b', label='Validation IoU')
plt.title('Training and validation IoU')
plt.legend()
plt.grid(True)
plt.show()  # Display IoU plot

# %%
# Hitung rata-rata untuk setiap metrik
avg_acc = np.mean(history.history['accuracy'])
avg_val_acc = np.mean(history.history['val_accuracy'])

avg_loss = np.mean(history.history['loss'])
avg_val_loss = np.mean(history.history['val_loss'])

avg_iou = np.mean(history.history['iou_metric'])
avg_val_iou = np.mean(history.history['val_iou_metric'])

# Cetak hasil rata-rata
print("=== Average Results Training ===")
print(f"Average Training Accuracy   : {avg_acc:.4f}")
print(f"Average Validation Accuracy : {avg_val_acc:.4f}")
print(f"Average Training Loss       : {avg_loss:.4f}")
print(f"Average Validation Loss     : {avg_val_loss:.4f}")
print(f"Average Training IoU        : {avg_iou:.4f}")
print(f"Average Validation IoU      : {avg_val_iou:.4f}")
