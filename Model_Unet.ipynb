# %% [markdown]
# <div style="text-align: center; font-size: 40px; font-weight: bold;">
#     Train Model U-Net Architecture
# </div>

# %% [markdown]
# # Libraries

# %%
import os
import numpy as np
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm
from PIL import Image
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
import tensorflow.keras.backend as K
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from skimage.transform import resize
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
# Out:
# Segmentation Models: using `tf.keras` framework.

# %% [markdown]
# # Functions

# %%
def map_mask_to_classes(mask_array: np.ndarray) -> np.ndarray:
    """
    Maps a binary mask to class labels.
    
    Args:
        mask_array (np.ndarray): Input mask array.
        
    Returns:
        np.ndarray: Binary mask with values mapped to 0 and 1.
    """
    return (mask_array > 0).astype(np.uint8)

# %%
def load_images_and_masks(image_folder: str, mask_folder: str, img_height: int, img_width: int) -> tuple:
    """
    Loads images and masks from specified folders, normalizes images, and processes masks.
    
    Args:
        image_folder (str): Path to the image folder.
        mask_folder (str): Path to the mask folder.
        img_height (int): Target image height.
        img_width (int): Target image width.
        
    Returns:
        tuple: (numpy.ndarray of images, numpy.ndarray of masks)
    """
    images, masks = [], []
    
    image_files = sorted(os.listdir(image_folder))
    mask_files = sorted(os.listdir(mask_folder))
    
    for img_file, mask_file in zip(image_files, mask_files):
        img_path = os.path.join(image_folder, img_file)
        mask_path = os.path.join(mask_folder, mask_file)
        
        # Load and normalize image
        img = load_img(img_path, target_size=(img_height, img_width))
        img = img_to_array(img) / 255.0
        images.append(img)
        
        # Load and process mask
        mask = load_img(mask_path, target_size=(img_height, img_width), color_mode="grayscale")
        mask = img_to_array(mask).astype(np.int32).squeeze()
        masks.append(map_mask_to_classes(mask))
    
    return np.array(images), np.array(masks).reshape(-1, img_height, img_width, 1)

# %%
IMG_HEIGHT, IMG_WIDTH = 512, 512 
def unet_model(input_size: tuple = (IMG_HEIGHT, IMG_WIDTH, 3)) -> Model:
    """
    Builds a U-Net model for image segmentation.
    
    Args:
        input_size (tuple): Shape of the input image.
        
    Returns:
        Model: Compiled U-Net model.
    """
    inputs = Input(input_size)
    
    # Encoder
    def conv_block(x, filters):
        x = Conv2D(filters, (3, 3), activation='relu', padding='same')(x)
        x = Conv2D(filters, (3, 3), activation='relu', padding='same')(x)
        return x
    
    c1 = conv_block(inputs, 16)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = conv_block(p1, 32)
    p2 = MaxPooling2D((2, 2))(c2)
    
    c3 = conv_block(p2, 64)
    p3 = MaxPooling2D((2, 2))(c3)
    
    c4 = conv_block(p3, 128)
    p4 = MaxPooling2D((2, 2))(c4)
    
    # Bottleneck
    c5 = conv_block(p4, 256)
    
    # Decoder
    def upsample_block(x, skip, filters):
        x = Conv2DTranspose(filters, (2, 2), strides=(2, 2), padding='same')(x)
        x = concatenate([x, skip])
        x = conv_block(x, filters)
        return x
    
    c6 = upsample_block(c5, c4, 128)
    c7 = upsample_block(c6, c3, 64)
    c8 = upsample_block(c7, c2, 32)
    c9 = upsample_block(c8, c1, 16)
    
    # Output layer with sigmoid activation
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    
    return Model(inputs, outputs)

# %%
def iou_metric(y_true, y_pred, smooth: float = 1e-6) -> float:
    """
    Computes the Intersection over Union (IoU) metric.
    
    Args:
        y_true: Ground truth binary mask.
        y_pred: Predicted binary mask.
        smooth (float): Smoothing factor to avoid division by zero.
    
    Returns:
        float: IoU score.
    """
    y_pred = K.cast(y_pred > 0.5, dtype='float32')
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred) - intersection
    return (intersection + smooth) / (union + smooth)

# %%
def dice_loss(y_true, y_pred, smooth: float = 1e-6) -> tf.Tensor:
    """
    Computes the Dice loss for image segmentation.
    
    Args:
        y_true: Ground truth binary mask.
        y_pred: Predicted mask.
        smooth (float): Smoothing factor to avoid division by zero.
    
    Returns:
        tf.Tensor: Dice loss value.
    """
    y_true = tf.cast(y_true, tf.float32)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    
    return 1 - ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))

# %% [markdown]
# # Load Images

# %%
# Folder path
folder_path = "Data_mask"

# Sorted images
image_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".bmp")])

# Select the first five images
selected_images = image_files[:5]

# Show images for horizontal structure form
fig, axes = plt.subplots(1, 5, figsize=(15, 5))

# Looping to call the images
for i, img_name in enumerate(selected_images):
    img_path = os.path.join(folder_path, img_name)
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  

    axes[i].imshow(img, cmap="gray")
    axes[i].axis("off")
    axes[i].set_title(f"Sample {i}")

# Plot the images
plt.tight_layout()
plt.show()

# %%
mask_path = "Data_mask/mask_CLAHE_dlm0000.bmp"
mask = Image.open(mask_path)
plt.imshow(mask, cmap='gray')
plt.title("Mask Ground Truth")
plt.axis('off')
plt.show()

# Check unique value on the mask
mask_array = np.array(mask)
print(f"Unique value form masking image: {np.unique(mask_array)}")
# Out:
# Unique value form masking image: [  0 255]

# %% [markdown]
# # Splitting Dataset

# %%
# Load dataset train and validation
train_images, train_masks = load_images_and_masks('Data_split/train/images', 'Data_split/train/masks', IMG_HEIGHT, IMG_WIDTH)
val_images, val_masks = load_images_and_masks('Data_split/valid/images', 'Data_split/valid/masks', IMG_HEIGHT, IMG_WIDTH)

print(f"Shape train_images: {train_images.shape}")
print(f"Shape train_masks: {train_masks.shape}")
# Out:
# Shape train_images: (595, 512, 512, 3)
# Shape train_masks: (595, 512, 512, 1)

# %%
# Buat model
model = unet_model()

# Kompilasi model
# ======= Kompilasi Model =======
model.compile(optimizer='adam',
              loss=dice_loss,
              metrics=['accuracy', iou_metric])

# ======= Callbacks =======
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

lr_reduce = ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.5, 
                              patience=5, 
                              min_lr=1e-6,
                              verbose=1)

model_checkpoint = ModelCheckpoint('Model/model_unet.h5', 
                                   monitor='val_loss', 
                                   save_best_only=True, 
                                   verbose=1)

callbacks = [early_stop, lr_reduce, model_checkpoint]
# ======= Training Contoh =======
history = model.fit(train_images, train_masks,
                    validation_data=(val_images, val_masks),
                    epochs=100,
                    callbacks=callbacks)
# Out:
# 2025-10-09 10:20:26.012989: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2025-10-09 10:20:26.013160: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-10-09 10:20:26.013464: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2025-10-09 10:20:26.014141: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-10-09 10:20:26.014743: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/100
# 2025-10-09 10:20:29.528635: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 19/19 [==============================] - ETA: 0s - loss: 0.8349 - accuracy: 0.5246 - iou_metric: 0.1670
# 2025-10-09 10:23:53.488190: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 0.76068, saving model to Model/model_unet.h5
# 19/19 [==============================] - 207s 10s/step - loss: 0.8349 - accuracy: 0.5246 - iou_metric: 0.1670 - val_loss: 0.7607 - val_accuracy: 0.9494 - val_iou_metric: 0.5314 - lr: 0.0010
# Epoch 2/100
# /Users/muhammadreesarosyid/tensorflow-test/env/lib/python3.9/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 19/19 [==============================] - ETA: 0s - loss: 0.7186 - accuracy: 0.8033 - iou_metric: 0.2424
# Epoch 2: val_loss improved from 0.76068 to 0.56177, saving model to Model/model_unet.h5
# 19/19 [==============================] - 157s 8s/step - loss: 0.7186 - accuracy: 0.8033 - iou_metric: 0.2424 - val_loss: 0.5618 - val_accuracy: 0.8715 - val_iou_metric: 0.3938 - lr: 0.0010
# Epoch 3/100
# 19/19 [==============================] - ETA: 0s - loss: 0.3857 - accuracy: 0.9375 - iou_metric: 0.4898
# Epoch 3: val_loss improved from 0.56177 to 0.30968, saving model to Model/model_unet.h5
# 19/19 [==============================] - 163s 8s/step - loss: 0.3857 - accuracy: 0.9375 - iou_metric: 0.4898 - val_loss: 0.3097 - val_accuracy: 0.9485 - val_iou_metric: 0.5460 - lr: 0.0010
# Epoch 4/100
# 19/19 [==============================] - ETA: 0s - loss: 0.3135 - accuracy: 0.9460 - iou_metric: 0.5397
# Epoch 4: val_loss improved from 0.30968 to 0.27939, saving model to Model/model_unet.h5
# 19/19 [==============================] - 150s 8s/step - loss: 0.3135 - accuracy: 0.9460 - iou_metric: 0.5397 - val_loss: 0.2794 - val_accuracy: 0.9488 - val_iou_metric: 0.5820 - lr: 0.0010
# Epoch 5/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2787 - accuracy: 0.9521 - iou_metric: 0.5813
# Epoch 5: val_loss improved from 0.27939 to 0.25878, saving model to Model/model_unet.h5
# 19/19 [==============================] - 145s 7s/step - loss: 0.2787 - accuracy: 0.9521 - iou_metric: 0.5813 - val_loss: 0.2588 - val_accuracy: 0.9540 - val_iou_metric: 0.6057 - lr: 0.0010
# Epoch 6/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2647 - accuracy: 0.9547 - iou_metric: 0.5962
# Epoch 6: val_loss did not improve from 0.25878
# 19/19 [==============================] - 136s 7s/step - loss: 0.2647 - accuracy: 0.9547 - iou_metric: 0.5962 - val_loss: 0.3031 - val_accuracy: 0.9332 - val_iou_metric: 0.5572 - lr: 0.0010
# Epoch 7/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2608 - accuracy: 0.9544 - iou_metric: 0.6014
# Epoch 7: val_loss improved from 0.25878 to 0.24078, saving model to Model/model_unet.h5
# 19/19 [==============================] - 150s 8s/step - loss: 0.2608 - accuracy: 0.9544 - iou_metric: 0.6014 - val_loss: 0.2408 - val_accuracy: 0.9607 - val_iou_metric: 0.6243 - lr: 0.0010
# Epoch 8/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2300 - accuracy: 0.9613 - iou_metric: 0.6424
# Epoch 8: val_loss improved from 0.24078 to 0.21905, saving model to Model/model_unet.h5
# 19/19 [==============================] - 142s 7s/step - loss: 0.2300 - accuracy: 0.9613 - iou_metric: 0.6424 - val_loss: 0.2190 - val_accuracy: 0.9602 - val_iou_metric: 0.6631 - lr: 0.0010
# Epoch 9/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2194 - accuracy: 0.9632 - iou_metric: 0.6596
# Epoch 9: val_loss improved from 0.21905 to 0.20164, saving model to Model/model_unet.h5
# 19/19 [==============================] - 140s 7s/step - loss: 0.2194 - accuracy: 0.9632 - iou_metric: 0.6596 - val_loss: 0.2016 - val_accuracy: 0.9656 - val_iou_metric: 0.6843 - lr: 0.0010
# Epoch 10/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2045 - accuracy: 0.9662 - iou_metric: 0.6801
# Epoch 10: val_loss improved from 0.20164 to 0.20148, saving model to Model/model_unet.h5
# 19/19 [==============================] - 148s 8s/step - loss: 0.2045 - accuracy: 0.9662 - iou_metric: 0.6801 - val_loss: 0.2015 - val_accuracy: 0.9630 - val_iou_metric: 0.6856 - lr: 0.0010
# Epoch 11/100
# 19/19 [==============================] - ETA: 0s - loss: 0.2021 - accuracy: 0.9662 - iou_metric: 0.6814
# Epoch 11: val_loss improved from 0.20148 to 0.18776, saving model to Model/model_unet.h5
# 19/19 [==============================] - 147s 8s/step - loss: 0.2021 - accuracy: 0.9662 - iou_metric: 0.6814 - val_loss: 0.1878 - val_accuracy: 0.9690 - val_iou_metric: 0.7011 - lr: 0.0010
# Epoch 12/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1960 - accuracy: 0.9671 - iou_metric: 0.6892
# Epoch 12: val_loss improved from 0.18776 to 0.17975, saving model to Model/model_unet.h5
# 19/19 [==============================] - 143s 7s/step - loss: 0.1960 - accuracy: 0.9671 - iou_metric: 0.6892 - val_loss: 0.1798 - val_accuracy: 0.9704 - val_iou_metric: 0.7156 - lr: 0.0010
# Epoch 13/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9677 - iou_metric: 0.6917
# Epoch 13: val_loss did not improve from 0.17975
# 19/19 [==============================] - 178s 9s/step - loss: 0.1953 - accuracy: 0.9677 - iou_metric: 0.6917 - val_loss: 0.1868 - val_accuracy: 0.9658 - val_iou_metric: 0.7035 - lr: 0.0010
# Epoch 14/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1876 - accuracy: 0.9688 - iou_metric: 0.7009
# Epoch 14: val_loss did not improve from 0.17975
# 19/19 [==============================] - 154s 8s/step - loss: 0.1876 - accuracy: 0.9688 - iou_metric: 0.7009 - val_loss: 0.1981 - val_accuracy: 0.9617 - val_iou_metric: 0.6879 - lr: 0.0010
# Epoch 15/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1761 - accuracy: 0.9709 - iou_metric: 0.7191
# Epoch 15: val_loss improved from 0.17975 to 0.16689, saving model to Model/model_unet.h5
# 19/19 [==============================] - 132s 7s/step - loss: 0.1761 - accuracy: 0.9709 - iou_metric: 0.7191 - val_loss: 0.1669 - val_accuracy: 0.9711 - val_iou_metric: 0.7336 - lr: 0.0010
# Epoch 16/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1732 - accuracy: 0.9712 - iou_metric: 0.7218
# Epoch 16: val_loss did not improve from 0.16689
# 19/19 [==============================] - 141s 7s/step - loss: 0.1732 - accuracy: 0.9712 - iou_metric: 0.7218 - val_loss: 0.1680 - val_accuracy: 0.9733 - val_iou_metric: 0.7270 - lr: 0.0010
# Epoch 17/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1660 - accuracy: 0.9726 - iou_metric: 0.7311
# Epoch 17: val_loss improved from 0.16689 to 0.15381, saving model to Model/model_unet.h5
# 19/19 [==============================] - 129s 7s/step - loss: 0.1660 - accuracy: 0.9726 - iou_metric: 0.7311 - val_loss: 0.1538 - val_accuracy: 0.9738 - val_iou_metric: 0.7512 - lr: 0.0010
# Epoch 18/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1569 - accuracy: 0.9742 - iou_metric: 0.7453
# Epoch 18: val_loss did not improve from 0.15381
# 19/19 [==============================] - 132s 7s/step - loss: 0.1569 - accuracy: 0.9742 - iou_metric: 0.7453 - val_loss: 0.1586 - val_accuracy: 0.9749 - val_iou_metric: 0.7406 - lr: 0.0010
# Epoch 19/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1592 - accuracy: 0.9736 - iou_metric: 0.7413
# Epoch 19: val_loss improved from 0.15381 to 0.14506, saving model to Model/model_unet.h5
# 19/19 [==============================] - 130s 7s/step - loss: 0.1592 - accuracy: 0.9736 - iou_metric: 0.7413 - val_loss: 0.1451 - val_accuracy: 0.9762 - val_iou_metric: 0.7624 - lr: 0.0010
# Epoch 20/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 0.9755 - iou_metric: 0.7564
# Epoch 20: val_loss improved from 0.14506 to 0.14272, saving model to Model/model_unet.h5
# 19/19 [==============================] - 133s 7s/step - loss: 0.1490 - accuracy: 0.9755 - iou_metric: 0.7564 - val_loss: 0.1427 - val_accuracy: 0.9758 - val_iou_metric: 0.7666 - lr: 0.0010
# Epoch 21/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1500 - accuracy: 0.9752 - iou_metric: 0.7538
# Epoch 21: val_loss improved from 0.14272 to 0.13774, saving model to Model/model_unet.h5
# 19/19 [==============================] - 131s 7s/step - loss: 0.1500 - accuracy: 0.9752 - iou_metric: 0.7538 - val_loss: 0.1377 - val_accuracy: 0.9769 - val_iou_metric: 0.7734 - lr: 0.0010
# Epoch 22/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1576 - accuracy: 0.9736 - iou_metric: 0.7408
# Epoch 22: val_loss did not improve from 0.13774
# 19/19 [==============================] - 132s 7s/step - loss: 0.1576 - accuracy: 0.9736 - iou_metric: 0.7408 - val_loss: 0.1397 - val_accuracy: 0.9758 - val_iou_metric: 0.7698 - lr: 0.0010
# Epoch 23/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1498 - accuracy: 0.9752 - iou_metric: 0.7538
# Epoch 23: val_loss improved from 0.13774 to 0.13257, saving model to Model/model_unet.h5
# 19/19 [==============================] - 127s 7s/step - loss: 0.1498 - accuracy: 0.9752 - iou_metric: 0.7538 - val_loss: 0.1326 - val_accuracy: 0.9776 - val_iou_metric: 0.7818 - lr: 0.0010
# Epoch 24/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1355 - accuracy: 0.9778 - iou_metric: 0.7765
# Epoch 24: val_loss improved from 0.13257 to 0.12862, saving model to Model/model_unet.h5
# 19/19 [==============================] - 134s 7s/step - loss: 0.1355 - accuracy: 0.9778 - iou_metric: 0.7765 - val_loss: 0.1286 - val_accuracy: 0.9789 - val_iou_metric: 0.7881 - lr: 0.0010
# Epoch 25/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1341 - accuracy: 0.9780 - iou_metric: 0.7787
# Epoch 25: val_loss improved from 0.12862 to 0.12498, saving model to Model/model_unet.h5
# 19/19 [==============================] - 129s 7s/step - loss: 0.1341 - accuracy: 0.9780 - iou_metric: 0.7787 - val_loss: 0.1250 - val_accuracy: 0.9793 - val_iou_metric: 0.7936 - lr: 0.0010
# Epoch 26/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1325 - accuracy: 0.9783 - iou_metric: 0.7796
# Epoch 26: val_loss did not improve from 0.12498
# 19/19 [==============================] - 123s 7s/step - loss: 0.1325 - accuracy: 0.9783 - iou_metric: 0.7796 - val_loss: 0.1354 - val_accuracy: 0.9755 - val_iou_metric: 0.7760 - lr: 0.0010
# Epoch 27/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1284 - accuracy: 0.9788 - iou_metric: 0.7870
# Epoch 27: val_loss did not improve from 0.12498
# 19/19 [==============================] - 125s 7s/step - loss: 0.1284 - accuracy: 0.9788 - iou_metric: 0.7870 - val_loss: 0.1261 - val_accuracy: 0.9797 - val_iou_metric: 0.7890 - lr: 0.0010
# Epoch 28/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1297 - accuracy: 0.9786 - iou_metric: 0.7835
# Epoch 28: val_loss improved from 0.12498 to 0.12072, saving model to Model/model_unet.h5
# 19/19 [==============================] - 158s 8s/step - loss: 0.1297 - accuracy: 0.9786 - iou_metric: 0.7835 - val_loss: 0.1207 - val_accuracy: 0.9802 - val_iou_metric: 0.7983 - lr: 0.0010
# Epoch 29/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1261 - accuracy: 0.9791 - iou_metric: 0.7892
# Epoch 29: val_loss did not improve from 0.12072
# 19/19 [==============================] - 155s 8s/step - loss: 0.1261 - accuracy: 0.9791 - iou_metric: 0.7892 - val_loss: 0.1260 - val_accuracy: 0.9797 - val_iou_metric: 0.7881 - lr: 0.0010
# Epoch 30/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1206 - accuracy: 0.9802 - iou_metric: 0.7989
# Epoch 30: val_loss improved from 0.12072 to 0.11603, saving model to Model/model_unet.h5
# 19/19 [==============================] - 141s 7s/step - loss: 0.1206 - accuracy: 0.9802 - iou_metric: 0.7989 - val_loss: 0.1160 - val_accuracy: 0.9801 - val_iou_metric: 0.8066 - lr: 0.0010
# Epoch 31/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1244 - accuracy: 0.9793 - iou_metric: 0.7910
# Epoch 31: val_loss did not improve from 0.11603
# 19/19 [==============================] - 149s 8s/step - loss: 0.1244 - accuracy: 0.9793 - iou_metric: 0.7910 - val_loss: 0.1305 - val_accuracy: 0.9791 - val_iou_metric: 0.7784 - lr: 0.0010
# Epoch 32/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1228 - accuracy: 0.9796 - iou_metric: 0.7931
# Epoch 32: val_loss improved from 0.11603 to 0.11507, saving model to Model/model_unet.h5
# 19/19 [==============================] - 147s 8s/step - loss: 0.1228 - accuracy: 0.9796 - iou_metric: 0.7931 - val_loss: 0.1151 - val_accuracy: 0.9812 - val_iou_metric: 0.8060 - lr: 0.0010
# Epoch 33/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1243 - accuracy: 0.9793 - iou_metric: 0.7905
# Epoch 33: val_loss improved from 0.11507 to 0.11275, saving model to Model/model_unet.h5
# 19/19 [==============================] - 140s 7s/step - loss: 0.1243 - accuracy: 0.9793 - iou_metric: 0.7905 - val_loss: 0.1128 - val_accuracy: 0.9814 - val_iou_metric: 0.8097 - lr: 0.0010
# Epoch 34/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1165 - accuracy: 0.9808 - iou_metric: 0.8034
# Epoch 34: val_loss improved from 0.11275 to 0.11049, saving model to Model/model_unet.h5
# 19/19 [==============================] - 139s 7s/step - loss: 0.1165 - accuracy: 0.9808 - iou_metric: 0.8034 - val_loss: 0.1105 - val_accuracy: 0.9810 - val_iou_metric: 0.8141 - lr: 0.0010
# Epoch 35/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.9810 - iou_metric: 0.8055
# Epoch 35: val_loss did not improve from 0.11049
# 19/19 [==============================] - 125s 7s/step - loss: 0.1149 - accuracy: 0.9810 - iou_metric: 0.8055 - val_loss: 0.1155 - val_accuracy: 0.9794 - val_iou_metric: 0.8049 - lr: 0.0010
# Epoch 36/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1221 - accuracy: 0.9794 - iou_metric: 0.7926
# Epoch 36: val_loss improved from 0.11049 to 0.10825, saving model to Model/model_unet.h5
# 19/19 [==============================] - 132s 7s/step - loss: 0.1221 - accuracy: 0.9794 - iou_metric: 0.7926 - val_loss: 0.1082 - val_accuracy: 0.9817 - val_iou_metric: 0.8165 - lr: 0.0010
# Epoch 37/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1124 - accuracy: 0.9814 - iou_metric: 0.8092
# Epoch 37: val_loss did not improve from 0.10825
# 19/19 [==============================] - 125s 7s/step - loss: 0.1124 - accuracy: 0.9814 - iou_metric: 0.8092 - val_loss: 0.1172 - val_accuracy: 0.9789 - val_iou_metric: 0.8018 - lr: 0.0010
# Epoch 38/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9813 - iou_metric: 0.8082
# Epoch 38: val_loss improved from 0.10825 to 0.10297, saving model to Model/model_unet.h5
# 19/19 [==============================] - 120s 6s/step - loss: 0.1125 - accuracy: 0.9813 - iou_metric: 0.8082 - val_loss: 0.1030 - val_accuracy: 0.9825 - val_iou_metric: 0.8253 - lr: 0.0010
# Epoch 39/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1072 - accuracy: 0.9823 - iou_metric: 0.8174
# Epoch 39: val_loss improved from 0.10297 to 0.10050, saving model to Model/model_unet.h5
# 19/19 [==============================] - 117s 6s/step - loss: 0.1072 - accuracy: 0.9823 - iou_metric: 0.8174 - val_loss: 0.1005 - val_accuracy: 0.9830 - val_iou_metric: 0.8289 - lr: 0.0010
# Epoch 40/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1047 - accuracy: 0.9827 - iou_metric: 0.8220
# Epoch 40: val_loss did not improve from 0.10050
# 19/19 [==============================] - 127s 7s/step - loss: 0.1047 - accuracy: 0.9827 - iou_metric: 0.8220 - val_loss: 0.1052 - val_accuracy: 0.9818 - val_iou_metric: 0.8206 - lr: 0.0010
# Epoch 41/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1048 - accuracy: 0.9826 - iou_metric: 0.8204
# Epoch 41: val_loss did not improve from 0.10050
# 19/19 [==============================] - 136s 7s/step - loss: 0.1048 - accuracy: 0.9826 - iou_metric: 0.8204 - val_loss: 0.1013 - val_accuracy: 0.9833 - val_iou_metric: 0.8263 - lr: 0.0010
# Epoch 42/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1057 - accuracy: 0.9825 - iou_metric: 0.8189
# Epoch 42: val_loss improved from 0.10050 to 0.09835, saving model to Model/model_unet.h5
# 19/19 [==============================] - 126s 7s/step - loss: 0.1057 - accuracy: 0.9825 - iou_metric: 0.8189 - val_loss: 0.0983 - val_accuracy: 0.9835 - val_iou_metric: 0.8315 - lr: 0.0010
# Epoch 43/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1063 - accuracy: 0.9823 - iou_metric: 0.8173
# Epoch 43: val_loss did not improve from 0.09835
# 19/19 [==============================] - 122s 6s/step - loss: 0.1063 - accuracy: 0.9823 - iou_metric: 0.8173 - val_loss: 0.1205 - val_accuracy: 0.9806 - val_iou_metric: 0.7916 - lr: 0.0010
# Epoch 44/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9818 - iou_metric: 0.8123
# Epoch 44: val_loss improved from 0.09835 to 0.09669, saving model to Model/model_unet.h5
# 19/19 [==============================] - 127s 7s/step - loss: 0.1089 - accuracy: 0.9818 - iou_metric: 0.8123 - val_loss: 0.0967 - val_accuracy: 0.9836 - val_iou_metric: 0.8337 - lr: 0.0010
# Epoch 45/100
# 19/19 [==============================] - ETA: 0s - loss: 0.1006 - accuracy: 0.9833 - iou_metric: 0.8267
# Epoch 45: val_loss improved from 0.09669 to 0.09279, saving model to Model/model_unet.h5
# 19/19 [==============================] - 143s 7s/step - loss: 0.1006 - accuracy: 0.9833 - iou_metric: 0.8267 - val_loss: 0.0928 - val_accuracy: 0.9845 - val_iou_metric: 0.8405 - lr: 0.0010
# Epoch 46/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0959 - accuracy: 0.9842 - iou_metric: 0.8349
# Epoch 46: val_loss improved from 0.09279 to 0.09203, saving model to Model/model_unet.h5
# 19/19 [==============================] - 221s 12s/step - loss: 0.0959 - accuracy: 0.9842 - iou_metric: 0.8349 - val_loss: 0.0920 - val_accuracy: 0.9847 - val_iou_metric: 0.8414 - lr: 0.0010
# Epoch 47/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0949 - accuracy: 0.9844 - iou_metric: 0.8369
# Epoch 47: val_loss did not improve from 0.09203
# 19/19 [==============================] - 1568s 87s/step - loss: 0.0949 - accuracy: 0.9844 - iou_metric: 0.8369 - val_loss: 0.0974 - val_accuracy: 0.9827 - val_iou_metric: 0.8324 - lr: 0.0010
# Epoch 48/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.9848 - iou_metric: 0.8417
# Epoch 48: val_loss improved from 0.09203 to 0.08758, saving model to Model/model_unet.h5
# 19/19 [==============================] - 120s 6s/step - loss: 0.0918 - accuracy: 0.9848 - iou_metric: 0.8417 - val_loss: 0.0876 - val_accuracy: 0.9854 - val_iou_metric: 0.8487 - lr: 0.0010
# Epoch 49/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0882 - accuracy: 0.9855 - iou_metric: 0.8476
# Epoch 49: val_loss improved from 0.08758 to 0.08591, saving model to Model/model_unet.h5
# 19/19 [==============================] - 118s 6s/step - loss: 0.0882 - accuracy: 0.9855 - iou_metric: 0.8476 - val_loss: 0.0859 - val_accuracy: 0.9857 - val_iou_metric: 0.8516 - lr: 0.0010
# Epoch 50/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0882 - accuracy: 0.9855 - iou_metric: 0.8475
# Epoch 50: val_loss improved from 0.08591 to 0.08518, saving model to Model/model_unet.h5
# 19/19 [==============================] - 112s 6s/step - loss: 0.0882 - accuracy: 0.9855 - iou_metric: 0.8475 - val_loss: 0.0852 - val_accuracy: 0.9855 - val_iou_metric: 0.8528 - lr: 0.0010
# Epoch 51/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0876 - accuracy: 0.9856 - iou_metric: 0.8481
# Epoch 51: val_loss did not improve from 0.08518
# 19/19 [==============================] - 112s 6s/step - loss: 0.0876 - accuracy: 0.9856 - iou_metric: 0.8481 - val_loss: 0.0854 - val_accuracy: 0.9853 - val_iou_metric: 0.8521 - lr: 0.0010
# Epoch 52/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0857 - accuracy: 0.9859 - iou_metric: 0.8516
# Epoch 52: val_loss did not improve from 0.08518
# 19/19 [==============================] - 112s 6s/step - loss: 0.0857 - accuracy: 0.9859 - iou_metric: 0.8516 - val_loss: 0.0958 - val_accuracy: 0.9827 - val_iou_metric: 0.8331 - lr: 0.0010
# Epoch 53/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9852 - iou_metric: 0.8461
# Epoch 53: val_loss improved from 0.08518 to 0.08303, saving model to Model/model_unet.h5
# 19/19 [==============================] - 106s 6s/step - loss: 0.0884 - accuracy: 0.9852 - iou_metric: 0.8461 - val_loss: 0.0830 - val_accuracy: 0.9857 - val_iou_metric: 0.8557 - lr: 0.0010
# Epoch 54/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.9854 - iou_metric: 0.8467
# Epoch 54: val_loss did not improve from 0.08303
# 19/19 [==============================] - 106s 6s/step - loss: 0.0879 - accuracy: 0.9854 - iou_metric: 0.8467 - val_loss: 0.0876 - val_accuracy: 0.9855 - val_iou_metric: 0.8466 - lr: 0.0010
# Epoch 55/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9859 - iou_metric: 0.8514
# Epoch 55: val_loss improved from 0.08303 to 0.08069, saving model to Model/model_unet.h5
# 19/19 [==============================] - 110s 6s/step - loss: 0.0851 - accuracy: 0.9859 - iou_metric: 0.8514 - val_loss: 0.0807 - val_accuracy: 0.9864 - val_iou_metric: 0.8593 - lr: 0.0010
# Epoch 56/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9870 - iou_metric: 0.8618
# Epoch 56: val_loss improved from 0.08069 to 0.07787, saving model to Model/model_unet.h5
# 19/19 [==============================] - 110s 6s/step - loss: 0.0792 - accuracy: 0.9870 - iou_metric: 0.8618 - val_loss: 0.0779 - val_accuracy: 0.9870 - val_iou_metric: 0.8643 - lr: 0.0010
# Epoch 57/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0817 - accuracy: 0.9865 - iou_metric: 0.8570
# Epoch 57: val_loss did not improve from 0.07787
# 19/19 [==============================] - 111s 6s/step - loss: 0.0817 - accuracy: 0.9865 - iou_metric: 0.8570 - val_loss: 0.0800 - val_accuracy: 0.9865 - val_iou_metric: 0.8599 - lr: 0.0010
# Epoch 58/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.9873 - iou_metric: 0.8648
# Epoch 58: val_loss improved from 0.07787 to 0.07618, saving model to Model/model_unet.h5
# 19/19 [==============================] - 109s 6s/step - loss: 0.0775 - accuracy: 0.9873 - iou_metric: 0.8648 - val_loss: 0.0762 - val_accuracy: 0.9871 - val_iou_metric: 0.8672 - lr: 0.0010
# Epoch 59/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.9880 - iou_metric: 0.8719
# Epoch 59: val_loss did not improve from 0.07618
# 19/19 [==============================] - 108s 6s/step - loss: 0.0735 - accuracy: 0.9880 - iou_metric: 0.8719 - val_loss: 0.0833 - val_accuracy: 0.9852 - val_iou_metric: 0.8541 - lr: 0.0010
# Epoch 60/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0764 - accuracy: 0.9874 - iou_metric: 0.8661
# Epoch 60: val_loss improved from 0.07618 to 0.07550, saving model to Model/model_unet.h5
# 19/19 [==============================] - 110s 6s/step - loss: 0.0764 - accuracy: 0.9874 - iou_metric: 0.8661 - val_loss: 0.0755 - val_accuracy: 0.9871 - val_iou_metric: 0.8680 - lr: 0.0010
# Epoch 61/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.9879 - iou_metric: 0.8713
# Epoch 61: val_loss did not improve from 0.07550
# 19/19 [==============================] - 111s 6s/step - loss: 0.0735 - accuracy: 0.9879 - iou_metric: 0.8713 - val_loss: 0.0831 - val_accuracy: 0.9863 - val_iou_metric: 0.8530 - lr: 0.0010
# Epoch 62/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.9880 - iou_metric: 0.8720
# Epoch 62: val_loss improved from 0.07550 to 0.07351, saving model to Model/model_unet.h5
# 19/19 [==============================] - 110s 6s/step - loss: 0.0732 - accuracy: 0.9880 - iou_metric: 0.8720 - val_loss: 0.0735 - val_accuracy: 0.9874 - val_iou_metric: 0.8711 - lr: 0.0010
# Epoch 63/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9885 - iou_metric: 0.8769
# Epoch 63: val_loss did not improve from 0.07351
# 19/19 [==============================] - 111s 6s/step - loss: 0.0703 - accuracy: 0.9885 - iou_metric: 0.8769 - val_loss: 0.0793 - val_accuracy: 0.9870 - val_iou_metric: 0.8595 - lr: 0.0010
# Epoch 64/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9885 - iou_metric: 0.8767
# Epoch 64: val_loss did not improve from 0.07351
# 19/19 [==============================] - 113s 6s/step - loss: 0.0704 - accuracy: 0.9885 - iou_metric: 0.8767 - val_loss: 0.0870 - val_accuracy: 0.9841 - val_iou_metric: 0.8463 - lr: 0.0010
# Epoch 65/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0734 - accuracy: 0.9878 - iou_metric: 0.8711
# Epoch 65: val_loss improved from 0.07351 to 0.06975, saving model to Model/model_unet.h5
# 19/19 [==============================] - 118s 6s/step - loss: 0.0734 - accuracy: 0.9878 - iou_metric: 0.8711 - val_loss: 0.0697 - val_accuracy: 0.9884 - val_iou_metric: 0.8775 - lr: 0.0010
# Epoch 66/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.9892 - iou_metric: 0.8842
# Epoch 66: val_loss did not improve from 0.06975
# 19/19 [==============================] - 110s 6s/step - loss: 0.0661 - accuracy: 0.9892 - iou_metric: 0.8842 - val_loss: 0.0716 - val_accuracy: 0.9882 - val_iou_metric: 0.8737 - lr: 0.0010
# Epoch 67/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0650 - accuracy: 0.9894 - iou_metric: 0.8861
# Epoch 67: val_loss did not improve from 0.06975
# 19/19 [==============================] - 111s 6s/step - loss: 0.0650 - accuracy: 0.9894 - iou_metric: 0.8861 - val_loss: 0.0727 - val_accuracy: 0.9881 - val_iou_metric: 0.8714 - lr: 0.0010
# Epoch 68/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9884 - iou_metric: 0.8756
# Epoch 68: val_loss did not improve from 0.06975
# 19/19 [==============================] - 111s 6s/step - loss: 0.0704 - accuracy: 0.9884 - iou_metric: 0.8756 - val_loss: 0.0711 - val_accuracy: 0.9882 - val_iou_metric: 0.8743 - lr: 0.0010
# Epoch 69/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0653 - accuracy: 0.9893 - iou_metric: 0.8849
# Epoch 69: val_loss did not improve from 0.06975
# 19/19 [==============================] - 107s 6s/step - loss: 0.0653 - accuracy: 0.9893 - iou_metric: 0.8849 - val_loss: 0.0703 - val_accuracy: 0.9884 - val_iou_metric: 0.8757 - lr: 0.0010
# Epoch 70/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9895 - iou_metric: 0.8871
# Epoch 70: val_loss improved from 0.06975 to 0.06797, saving model to Model/model_unet.h5
# 19/19 [==============================] - 107s 6s/step - loss: 0.0643 - accuracy: 0.9895 - iou_metric: 0.8871 - val_loss: 0.0680 - val_accuracy: 0.9884 - val_iou_metric: 0.8801 - lr: 0.0010
# Epoch 71/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9896 - iou_metric: 0.8884
# Epoch 71: val_loss improved from 0.06797 to 0.06771, saving model to Model/model_unet.h5
# 19/19 [==============================] - 106s 6s/step - loss: 0.0636 - accuracy: 0.9896 - iou_metric: 0.8884 - val_loss: 0.0677 - val_accuracy: 0.9888 - val_iou_metric: 0.8802 - lr: 0.0010
# Epoch 72/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.9897 - iou_metric: 0.8896
# Epoch 72: val_loss improved from 0.06771 to 0.06602, saving model to Model/model_unet.h5
# 19/19 [==============================] - 110s 6s/step - loss: 0.0629 - accuracy: 0.9897 - iou_metric: 0.8896 - val_loss: 0.0660 - val_accuracy: 0.9887 - val_iou_metric: 0.8835 - lr: 0.0010
# Epoch 73/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0605 - accuracy: 0.9902 - iou_metric: 0.8940
# Epoch 73: val_loss did not improve from 0.06602
# 19/19 [==============================] - 109s 6s/step - loss: 0.0605 - accuracy: 0.9902 - iou_metric: 0.8940 - val_loss: 0.0664 - val_accuracy: 0.9890 - val_iou_metric: 0.8824 - lr: 0.0010
# Epoch 74/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 0.9905 - iou_metric: 0.8970
# Epoch 74: val_loss did not improve from 0.06602
# 19/19 [==============================] - 103s 5s/step - loss: 0.0589 - accuracy: 0.9905 - iou_metric: 0.8970 - val_loss: 0.0665 - val_accuracy: 0.9890 - val_iou_metric: 0.8819 - lr: 0.0010
# Epoch 75/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0608 - accuracy: 0.9901 - iou_metric: 0.8926
# Epoch 75: val_loss improved from 0.06602 to 0.06501, saving model to Model/model_unet.h5
# 19/19 [==============================] - 106s 6s/step - loss: 0.0608 - accuracy: 0.9901 - iou_metric: 0.8926 - val_loss: 0.0650 - val_accuracy: 0.9891 - val_iou_metric: 0.8849 - lr: 0.0010
# Epoch 76/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9899 - iou_metric: 0.8906
# Epoch 76: val_loss improved from 0.06501 to 0.06443, saving model to Model/model_unet.h5
# 19/19 [==============================] - 143s 8s/step - loss: 0.0618 - accuracy: 0.9899 - iou_metric: 0.8906 - val_loss: 0.0644 - val_accuracy: 0.9890 - val_iou_metric: 0.8857 - lr: 0.0010
# Epoch 77/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9898 - iou_metric: 0.8900
# Epoch 77: val_loss improved from 0.06443 to 0.06355, saving model to Model/model_unet.h5
# 19/19 [==============================] - 162s 8s/step - loss: 0.0621 - accuracy: 0.9898 - iou_metric: 0.8900 - val_loss: 0.0635 - val_accuracy: 0.9894 - val_iou_metric: 0.8872 - lr: 0.0010
# Epoch 78/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 0.9904 - iou_metric: 0.8957
# Epoch 78: val_loss improved from 0.06355 to 0.06259, saving model to Model/model_unet.h5
# 19/19 [==============================] - 1062s 59s/step - loss: 0.0591 - accuracy: 0.9904 - iou_metric: 0.8957 - val_loss: 0.0626 - val_accuracy: 0.9895 - val_iou_metric: 0.8891 - lr: 0.0010
# Epoch 79/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.9904 - iou_metric: 0.8964
# Epoch 79: val_loss did not improve from 0.06259
# 19/19 [==============================] - 183s 10s/step - loss: 0.0587 - accuracy: 0.9904 - iou_metric: 0.8964 - val_loss: 0.0642 - val_accuracy: 0.9890 - val_iou_metric: 0.8860 - lr: 0.0010
# Epoch 80/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0605 - accuracy: 0.9900 - iou_metric: 0.8929
# Epoch 80: val_loss did not improve from 0.06259
# 19/19 [==============================] - 124s 6s/step - loss: 0.0605 - accuracy: 0.9900 - iou_metric: 0.8929 - val_loss: 0.0628 - val_accuracy: 0.9895 - val_iou_metric: 0.8883 - lr: 0.0010
# Epoch 81/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0556 - accuracy: 0.9910 - iou_metric: 0.9021
# Epoch 81: val_loss did not improve from 0.06259
# 19/19 [==============================] - 118s 6s/step - loss: 0.0556 - accuracy: 0.9910 - iou_metric: 0.9021 - val_loss: 0.0710 - val_accuracy: 0.9883 - val_iou_metric: 0.8727 - lr: 0.0010
# Epoch 82/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9906 - iou_metric: 0.8983
# Epoch 82: val_loss did not improve from 0.06259
# 19/19 [==============================] - 717s 39s/step - loss: 0.0575 - accuracy: 0.9906 - iou_metric: 0.8983 - val_loss: 0.0650 - val_accuracy: 0.9893 - val_iou_metric: 0.8838 - lr: 0.0010
# Epoch 83/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9907 - iou_metric: 0.8994
# Epoch 83: val_loss improved from 0.06259 to 0.06097, saving model to Model/model_unet.h5
# 19/19 [==============================] - 390s 21s/step - loss: 0.0569 - accuracy: 0.9907 - iou_metric: 0.8994 - val_loss: 0.0610 - val_accuracy: 0.9897 - val_iou_metric: 0.8915 - lr: 0.0010
# Epoch 84/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.9913 - iou_metric: 0.9055
# Epoch 84: val_loss improved from 0.06097 to 0.06022, saving model to Model/model_unet.h5
# 19/19 [==============================] - 1461s 81s/step - loss: 0.0537 - accuracy: 0.9913 - iou_metric: 0.9055 - val_loss: 0.0602 - val_accuracy: 0.9900 - val_iou_metric: 0.8929 - lr: 0.0010
# Epoch 85/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9915 - iou_metric: 0.9071
# Epoch 85: val_loss did not improve from 0.06022
# 19/19 [==============================] - 120s 6s/step - loss: 0.0528 - accuracy: 0.9915 - iou_metric: 0.9071 - val_loss: 0.0645 - val_accuracy: 0.9894 - val_iou_metric: 0.8845 - lr: 0.0010
# Epoch 86/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0538 - accuracy: 0.9913 - iou_metric: 0.9049
# Epoch 86: val_loss did not improve from 0.06022
# 19/19 [==============================] - 112s 6s/step - loss: 0.0538 - accuracy: 0.9913 - iou_metric: 0.9049 - val_loss: 0.0626 - val_accuracy: 0.9896 - val_iou_metric: 0.8881 - lr: 0.0010
# Epoch 87/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9916 - iou_metric: 0.9088
# Epoch 87: val_loss did not improve from 0.06022
# 19/19 [==============================] - 117s 6s/step - loss: 0.0517 - accuracy: 0.9916 - iou_metric: 0.9088 - val_loss: 0.0614 - val_accuracy: 0.9894 - val_iou_metric: 0.8906 - lr: 0.0010
# Epoch 88/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9913 - iou_metric: 0.9059
# Epoch 88: val_loss improved from 0.06022 to 0.05977, saving model to Model/model_unet.h5
# 19/19 [==============================] - 497s 27s/step - loss: 0.0532 - accuracy: 0.9913 - iou_metric: 0.9059 - val_loss: 0.0598 - val_accuracy: 0.9900 - val_iou_metric: 0.8932 - lr: 0.0010
# Epoch 89/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9914 - iou_metric: 0.9066
# Epoch 89: val_loss did not improve from 0.05977
# 19/19 [==============================] - 523s 29s/step - loss: 0.0528 - accuracy: 0.9914 - iou_metric: 0.9066 - val_loss: 0.0628 - val_accuracy: 0.9896 - val_iou_metric: 0.8874 - lr: 0.0010
# Epoch 90/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9917 - iou_metric: 0.9097
# Epoch 90: val_loss improved from 0.05977 to 0.05903, saving model to Model/model_unet.h5
# 19/19 [==============================] - 1103s 61s/step - loss: 0.0511 - accuracy: 0.9917 - iou_metric: 0.9097 - val_loss: 0.0590 - val_accuracy: 0.9902 - val_iou_metric: 0.8943 - lr: 0.0010
# Epoch 91/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0530 - accuracy: 0.9913 - iou_metric: 0.9059
# Epoch 91: val_loss improved from 0.05903 to 0.05894, saving model to Model/model_unet.h5
# 19/19 [==============================] - 113s 6s/step - loss: 0.0530 - accuracy: 0.9913 - iou_metric: 0.9059 - val_loss: 0.0589 - val_accuracy: 0.9902 - val_iou_metric: 0.8945 - lr: 0.0010
# Epoch 92/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0512 - accuracy: 0.9917 - iou_metric: 0.9093
# Epoch 92: val_loss did not improve from 0.05894
# 19/19 [==============================] - 116s 6s/step - loss: 0.0512 - accuracy: 0.9917 - iou_metric: 0.9093 - val_loss: 0.0673 - val_accuracy: 0.9879 - val_iou_metric: 0.8788 - lr: 0.0010
# Epoch 93/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9903 - iou_metric: 0.8953
# Epoch 93: val_loss did not improve from 0.05894
# 19/19 [==============================] - 133s 7s/step - loss: 0.0584 - accuracy: 0.9903 - iou_metric: 0.8953 - val_loss: 0.0598 - val_accuracy: 0.9900 - val_iou_metric: 0.8925 - lr: 0.0010
# Epoch 94/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0538 - accuracy: 0.9911 - iou_metric: 0.9040
# Epoch 94: val_loss improved from 0.05894 to 0.05880, saving model to Model/model_unet.h5
# 19/19 [==============================] - 145s 8s/step - loss: 0.0538 - accuracy: 0.9911 - iou_metric: 0.9040 - val_loss: 0.0588 - val_accuracy: 0.9899 - val_iou_metric: 0.8947 - lr: 0.0010
# Epoch 95/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0522 - accuracy: 0.9914 - iou_metric: 0.9072
# Epoch 95: val_loss improved from 0.05880 to 0.05851, saving model to Model/model_unet.h5
# 19/19 [==============================] - 165s 9s/step - loss: 0.0522 - accuracy: 0.9914 - iou_metric: 0.9072 - val_loss: 0.0585 - val_accuracy: 0.9901 - val_iou_metric: 0.8951 - lr: 0.0010
# Epoch 96/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9920 - iou_metric: 0.9124
# Epoch 96: val_loss improved from 0.05851 to 0.05705, saving model to Model/model_unet.h5
# 19/19 [==============================] - 153s 8s/step - loss: 0.0495 - accuracy: 0.9920 - iou_metric: 0.9124 - val_loss: 0.0570 - val_accuracy: 0.9904 - val_iou_metric: 0.8976 - lr: 0.0010
# Epoch 97/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0481 - accuracy: 0.9922 - iou_metric: 0.9149
# Epoch 97: val_loss did not improve from 0.05705
# 19/19 [==============================] - 144s 7s/step - loss: 0.0481 - accuracy: 0.9922 - iou_metric: 0.9149 - val_loss: 0.0587 - val_accuracy: 0.9902 - val_iou_metric: 0.8944 - lr: 0.0010
# Epoch 98/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9922 - iou_metric: 0.9153
# Epoch 98: val_loss did not improve from 0.05705
# 19/19 [==============================] - 139s 7s/step - loss: 0.0479 - accuracy: 0.9922 - iou_metric: 0.9153 - val_loss: 0.0589 - val_accuracy: 0.9902 - val_iou_metric: 0.8941 - lr: 0.0010
# Epoch 99/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0472 - accuracy: 0.9924 - iou_metric: 0.9166
# Epoch 99: val_loss improved from 0.05705 to 0.05583, saving model to Model/model_unet.h5
# 19/19 [==============================] - 136s 7s/step - loss: 0.0472 - accuracy: 0.9924 - iou_metric: 0.9166 - val_loss: 0.0558 - val_accuracy: 0.9906 - val_iou_metric: 0.8998 - lr: 0.0010
# Epoch 100/100
# 19/19 [==============================] - ETA: 0s - loss: 0.0460 - accuracy: 0.9926 - iou_metric: 0.9192
# Epoch 100: val_loss did not improve from 0.05583
# 19/19 [==============================] - 147s 8s/step - loss: 0.0460 - accuracy: 0.9926 - iou_metric: 0.9192 - val_loss: 0.0564 - val_accuracy: 0.9906 - val_iou_metric: 0.8987 - lr: 0.0010

# %%
# Extract data from history.history
epochs = range(1, len(history.history['loss']) + 1)
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
iou = history.history['iou_metric']
val_iou = history.history['val_iou_metric']

# Plotting Training and Validation Accuracy
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.grid(True)
plt.show()  # Display accuracy plot

# Plotting Training and Validation Loss
plt.figure()
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.grid(True)
plt.show()  # Display loss plot

# Plotting Training and Validation IoU
plt.figure()
plt.plot(epochs, iou, 'r', label='Training IoU')
plt.plot(epochs, val_iou, 'b', label='Validation IoU')
plt.title('Training and validation IoU')
plt.legend()
plt.grid(True)
plt.show()  # Display IoU plot

# %%
# Hitung rata-rata untuk setiap metrik
avg_acc = np.mean(history.history['accuracy'])
avg_val_acc = np.mean(history.history['val_accuracy'])

avg_loss = np.mean(history.history['loss'])
avg_val_loss = np.mean(history.history['val_loss'])

avg_iou = np.mean(history.history['iou_metric'])
avg_val_iou = np.mean(history.history['val_iou_metric'])

# Cetak hasil rata-rata
print("=== Average Results Training ===")
print(f"Average Training Accuracy   : {avg_acc:.4f}")
print(f"Average Validation Accuracy : {avg_val_acc:.4f}")
print(f"Average Training Loss       : {avg_loss:.4f}")
print(f"Average Validation Loss     : {avg_val_loss:.4f}")
print(f"Average Training IoU        : {avg_iou:.4f}")
print(f"Average Validation IoU      : {avg_val_iou:.4f}")
# Out:
# === Average Results Training ===
# Average Training Accuracy   : 0.9757
# Average Validation Accuracy : 0.9802
# Average Training Loss       : 0.1215
# Average Validation Loss     : 0.1183
# Average Training IoU        : 0.8088
# Average Validation IoU      : 0.8140
